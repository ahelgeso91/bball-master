# %%
import requests

league_id = 1426889
year = 2018
url = "https://fantasy.espn.com/apis/v3/games/ffl/leagueHistory/" + \
      str(league_id) + "?seasonId=" + str(year)

r = requests.get(url)
d = r.json()[0]

# %%
d
# Out:
# {'gameId': 1,
#  'id': 1426889,
#  'members': [{'displayName': 'granderojo4',
#    'id': '{1958303D-65F2-4DA8-A91F-A01C9F47D972}',
#    'isLeagueManager': True},
#   {'displayName': 'Jalioto09',
#    'id': '{28CAFCCE-1D12-47C7-8AFC-CE1D1237C758}',
#    'isLeagueManager': False},
#   {'displayName': 'ahelgeso',
#    'id': '{4FBA3991-CD6F-4EC2-A371-A75820850018}',
#    'isLeagueManager': False},
#   {'displayName': 'bud-916',
#    'id': '{6BA0446F-5732-4C2B-BBFC-383DCBDCB102}',
#    'isLeagueManager': False},
#   {'displayName': 'Cdubasaur',
#    'id': '{899146B3-682C-489B-BC1D-7ABC3F2844AF}',
#    'isLeagueManager': False},
#   {'displayName': 'wgaebler',
#    'id': '{9A2CA27D-D29E-4E28-ACA2-7DD29E7E2829}',
#    'isLeagueManager': False},
#   {'displayName': 'steven3277756',
#    'id': '{C8850570-8195-4B12-9160-9DEBF88D7110}',
#    'isLeagueManager': False},
#   {'displayName': 'CamVRod',
#    'id': '{C9F55AF0-D8B2-4BD7-B57C-62C5C9A8E1AE}',
#    'isLeagueManager': False},
# ...
