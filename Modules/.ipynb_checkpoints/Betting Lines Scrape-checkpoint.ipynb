# %%
import pickle
import re
import requests, bs4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
db = pd.read_csv('2015stats.csv')

# %%
team_abbrevs = {
    'Cleveland': 'CLE',
    'Boston':'BOS',
    'Washington':'WAS',
    'Charlotte':'CHO',
    'Minnesota':'MIN',
    'Dallas':'DAL',
    'Milwaukee':'MIL',
    'Philadelphia':'PHI',
    'Phoenix':'PHO',
    'L.A. Lakers':'LAL',
    'Utah':'UTA',
    'Sacramento':'SAC',
    'New York':'NYK',
    'New Orleans':'NOP',
    'Detroit':'DET',
    'Atlanta':'ATL',
    'Chicago':'CHI',
    'Miami':'MIA',
    'Memphis':'MEM',
    'Golden State':'GSW',
    'Denver':'DEN',
    'Brooklyn':'BRK',
    'L.A. Clippers':'LAC',
    'Portland':'POR',
    'Indiana':'IND',
    'San Antonio':'SAS',
    'Houston':'HOU',
    'Oklahoma City':'OKC',
    'Toronto':'TOR',
    'Orlando':'ORL'
}

# %%
# Moneyline scrape
scraped_dates = []
moneydb = pd.DataFrame()

for date in db['Date']:
    
    if date not in scraped_dates:
        print("Date: ", date)
        url = f'https://www.sportsbookreview.com/betting-odds/nba-basketball/money-line/?date={date}'
        res = requests.get(url, 'html.parser')
        res.raise_for_status()
        soup = bs4.BeautifulSoup(res.text, 'lxml')
        linesoup = soup.find('div', {'id':'bettingOddsGridContainer'})
        test_teams = linesoup.find_all('span', {'class':'_3O1Gx'})
        teams = [team_abbrevs[team.get_text()] for team in test_teams]
        test_lines = linesoup.find_all('span', {'class':'opener'})
        lines = [line.get_text() for line in test_lines if line.get_text().startswith('-') and len(line.get_text()) > 1 or line.get_text().startswith('+') and len(line.get_text()) > 1]
        print("teams:",len(teams),"lines",len(lines))
        
                
        if len(teams) != len(lines):
            pass
        else:
            moneylines = {'Team':teams, 'ML Odds': lines, 'Date':[date]*len(teams)}
        
            MLdb = pd.DataFrame.from_dict(moneylines)
            moneydb = pd.concat([moneydb, MLdb])
            
        scraped_dates.append(date)
        
# moneydb.to_csv('MLodds.csv')
# Out:
# Date:  20141030
# teams: 10 lines 10
# Date:  20141031
# teams: 12 lines 12
# Date:  20141104
# teams: 16 lines 16
# Date:  20141105
# teams: 24 lines 24
# Date:  20141107
# teams: 22 lines 22
# Date:  20141110
# teams: 10 lines 10
# Date:  20141114
# teams: 20 lines 20
# Date:  20141115
# teams: 20 lines 20
# Date:  20141117
# teams: 18 lines 18
# Date:  20141119
# teams: 22 lines 22
# Date:  20141121
# teams: 24 lines 24
# Date:  20141122
# teams: 18 lines 18
# Date:  20141124
# teams: 14 lines 14
# Date:  20141126
# teams: 26 lines 26
# Date:  20141129
# teams: 12 lines 12
# Date:  20141202
# teams: 20 lines 20
# Date:  20141204
# teams: 6 lines 6
# Date:  20141205
# teams: 24 lines 24
# Date:  20141208
# teams: 14 lines 14
# Date:  20141209
# teams: 16 lines 16
# Date:  20141211
# teams: 4 lines 4
# Date:  20141212
# teams: 24 lines 24
# Date:  20141215
# teams: 16 lines 16
# Date:  20141217
# teams: 20 lines 20
# teams: 8 lines 8
# Date:  20150114
# teams: 20 lines 20
# Date:  20150122
# teams: 8 lines 8
# Date:  20150126
# teams: 14 lines 14
# Date:  20150201
# teams: 4 lines 4
# Date:  20150203
# teams: 10 lines 10
# Date:  20150204
# teams: 22 lines 22
# Date:  20150207
# teams: 14 lines 14
# Date:  20150223
# teams: 16 lines 16
# Date:  20150225
# teams: 24 lines 24
# Date:  20150308
# teams: 14 lines 14
# Date:  20150309
# teams: 16 lines 16
# Date:  20150311
# teams: 20 lines 20
# Date:  20150313
# teams: 18 lines 18
# Date:  20150314
# teams: 12 lines 12
# Date:  20150323
# teams: 12 lines 12
# Date:  20150330
# teams: 14 lines 14
# Date:  20150401
# teams: 24 lines 24
# Date:  20150403
# teams: 20 lines 20
# Date:  20150404
# teams: 20 lines 20
# Date:  20150414
# teams: 6 lines 6
# Date:  20141125
# teams: 10 lines 10
# Date:  20141201
# teams: 8 lines 8
# Date:  20141214
# teams: 14 lines 14
# Date:  20141216
# teams: 12 lines 12
# Date:  20141229
# teams: 12 lines 12
# Date:  20150117
# teams: 16 lines 16
# Date:  20150124
# teams: 10 lines 10
# Date:  20150209
# teams: 18 lines 18
# Date:  20150228
# teams: 14 lines 14
# Date:  20141102
# teams: 8 lines 8
# Date:  20141109
# teams: 16 lines 16
# Date:  20141111
# teams: 12 lines 12
# Date:  20141213
# teams: 16 lines 16
# Date:  20141220
# teams: 14 lines 14
# Date:  20141222
# teams: 14 lines 14
# Date:  20150108
# teams: 6 lines 6
# Date:  20150210
# teams: 10 lines 10
# Date:  20150221
# teams: 10 lines 10
# Date:  20150317
# teams: 10 lines 10
# Date:  20150328
# teams: 10 lines 10
# Date:  20150407
# teams: 12 lines 12
# Date:  20141206
# teams: 12 lines 12
# Date:  20150101
# teams: 4 lines 4
# Date:  20150302
# teams: 10 lines 10
# Date:  20150319
# teams: 8 lines 8
# Date:  20150411
# teams: 12 lines 12
# Date:  20141028
# teams: 6 lines 6
# Date:  20141106
# teams: 4 lines 4
# Date:  20141113
# teams: 8 lines 8
# Date:  20150219
# teams: 4 lines 4
# Date:  20150305
# teams: 4 lines 4
# Date:  20150324
# teams: 12 lines 12
# Date:  20141116
# teams: 8 lines 8
# Date:  20141118
# teams: 8 lines 8
# Date:  20141218
# teams: 8 lines 8
# Date:  20150106
# teams: 4 lines 4
# Date:  20150129
# teams: 8 lines 8
# Date:  20150326
# teams: 2 lines 2
# Date:  20150321
# teams: 10 lines 10
# Date:  20150118
# teams: 6 lines 6
# Date:  20141120
# teams: 4 lines 4
# Date:  20150331
# teams: 8 lines 8
# Date:  20150409
# teams: 4 lines 4
# Date:  20150120
# teams: 4 lines 4
# Date:  20150406
# teams: 2 lines 2

# %%
moneydb.to_csv('MLodds.csv', index = False)

# %%
# Point spread scrape
scraped_dates = []
spreaddb = pd.DataFrame()

for date in db['Date']:
    if date not in scraped_dates:
        print("Date: ", date)
        url = f'https://www.sportsbookreview.com/betting-odds/nba-basketball/pointspread/?date={date}'
        res = requests.get(url, 'html.parser')
        res.raise_for_status()
        soup = bs4.BeautifulSoup(res.text, 'lxml')
        linesoup = soup.find('div', {'id':'bettingOddsGridContainer'})
        test_teams = linesoup.find_all('span', {'class':'_3O1Gx'})
        teams = [team_abbrevs[team.get_text()] for team in test_teams]
        test_lines = linesoup.find_all('span', {'class':'_3Nv_7 opener'})
        lines = [line.get_text() for line in test_lines if line.get_text().startswith('-') or line.get_text().startswith('+') or line.get_text().startswith('P')]
        print("teams:",len(teams),"lines",len(lines))
        
        if len(teams) != len(lines):
            pass
        else:
            spreads = {'Team':teams, 'Spread': lines, 'Date':[date]*len(lines)}
            spreads = pd.DataFrame.from_dict(spreads)
            spreaddb = pd.concat([spreaddb, spreads])

        scraped_dates.append(date)

spreaddb.to_csv('Spreads.csv', index = False)
# Out:
# Date:  20141030
# teams: 10 lines 10
# Date:  20141031
# teams: 12 lines 12
# Date:  20141104
# teams: 16 lines 16
# Date:  20141105
# teams: 24 lines 24
# Date:  20141107
# teams: 22 lines 22
# Date:  20141110
# teams: 10 lines 10
# Date:  20141114
# teams: 20 lines 20
# Date:  20141115
# teams: 20 lines 20
# Date:  20141117
# teams: 18 lines 18
# Date:  20141119
# teams: 22 lines 22
# Date:  20141121
# teams: 24 lines 24
# Date:  20141122
# teams: 18 lines 18
# Date:  20141124
# teams: 14 lines 14
# Date:  20141126
# teams: 26 lines 26
# Date:  20141129
# teams: 12 lines 12
# Date:  20141202
# teams: 20 lines 20
# Date:  20141204
# teams: 6 lines 6
# Date:  20141205
# teams: 24 lines 24
# Date:  20141208
# teams: 14 lines 14
# Date:  20141209
# teams: 16 lines 16
# Date:  20141211
# teams: 4 lines 4
# Date:  20141212
# teams: 24 lines 24
# Date:  20141215
# teams: 16 lines 16
# Date:  20141217
# teams: 20 lines 20
# Date:  20141219
# teams: 20 lines 20
# Date:  20141221
# teams: 18 lines 18
# Date:  20141223
# teams: 22 lines 22
# Date:  20141225
# teams: 10 lines 10
# Date:  20141226
# teams: 22 lines 22
# Date:  20141228
# teams: 12 lines 12
# Date:  20141230
# teams: 20 lines 20
# Date:  20141231
# teams: 14 lines 14
# Date:  20150102
# teams: 22 lines 22
# Date:  20150104
# teams: 12 lines 12
# Date:  20150105
# teams: 22 lines 22
# Date:  20150107
# teams: 26 lines 26
# Date:  20150109
# teams: 22 lines 22
# Date:  20150111
# teams: 10 lines 10
# Date:  20150113
# teams: 14 lines 14
# Date:  20150115
# teams: 6 lines 6
# Date:  20150116
# teams: 26 lines 26
# Date:  20150119
# teams: 24 lines 24
# Date:  20150121
# teams: 24 lines 24
# Date:  20150123
# teams: 22 lines 22
# Date:  20150125
# teams: 22 lines 22
# Date:  20150127
# teams: 12 lines 12
# Date:  20150128
# teams: 22 lines 22
# Date:  20150130
# teams: 18 lines 18
# Date:  20150131
# teams: 22 lines 22
# Date:  20150202
# teams: 16 lines 16
# Date:  20150205
# teams: 8 lines 8
# Date:  20150206
# teams: 24 lines 24
# Date:  20150208
# Date:  20150228
# teams: 14 lines 14
# Date:  20141102
# teams: 8 lines 8
# Date:  20141109
# teams: 16 lines 16
# Date:  20141111
# teams: 12 lines 12
# Date:  20141213
# teams: 16 lines 16
# Date:  20141220
# teams: 14 lines 14
# Date:  20141222
# teams: 14 lines 14
# Date:  20150108
# teams: 6 lines 6
# Date:  20150210
# teams: 10 lines 10
# Date:  20150221
# teams: 10 lines 10
# Date:  20150317
# teams: 10 lines 10
# Date:  20150328
# teams: 10 lines 10
# Date:  20150407
# teams: 12 lines 12
# Date:  20141206
# teams: 12 lines 12
# Date:  20150101
# teams: 4 lines 4
# Date:  20150302
# teams: 10 lines 10
# Date:  20150319
# teams: 8 lines 8
# Date:  20150411
# teams: 12 lines 12
# Date:  20141028
# teams: 6 lines 6
# Date:  20141106
# teams: 4 lines 4
# Date:  20141113
# teams: 8 lines 8
# Date:  20150219
# teams: 4 lines 4
# Date:  20150305
# teams: 4 lines 4
# Date:  20150324
# teams: 12 lines 12
# Date:  20141116
# teams: 8 lines 8
# Date:  20141118
# teams: 8 lines 8
# Date:  20141218
# teams: 8 lines 8
# Date:  20150106
# teams: 4 lines 4
# Date:  20150129
# teams: 8 lines 8
# Date:  20150326
# teams: 2 lines 2
# Date:  20150321
# teams: 10 lines 10
# Date:  20150118
# teams: 6 lines 6
# Date:  20141120
# teams: 4 lines 4
# Date:  20150331
# teams: 8 lines 8
# Date:  20150409
# teams: 4 lines 4
# Date:  20150120
# teams: 4 lines 4
# Date:  20150406
# teams: 2 lines 2

# %%
db['Odds'] = np.zeros(len(db['Team']))
db['Line'] = np.zeros(len(db['Team']))

# %%
date=db['Date'][0]
team = db['Team'][0]
print(date, team)
# Out:
# 20141030 CLE

# %%
#db['Odds'][0] = moneydb[(moneydb['Date'] == date) & (moneydb['Team'] == db['Team'][0])]['ML Odds']
#db['Line'][0] = spreaddb[(spreaddb['Date'] == date) & (spreaddb['Team'] == db['Team'][0])]['Spread']

moneydb.reset_index(drop = True, inplace = True)
spreaddb.reset_index(drop = True, inplace = True)

# %%
print(re.sub("½", ".5", spreaddb['Spread'][0]))

for i, spread in enumerate(spreaddb['Spread']):
    spreaddb['Spread'][i] = re.sub("½", ".5", spread)
    print(spreaddb['Spread'][i])
# Out:
# -3.5
# -3.5
# +3.5
# +11.5
# -11.5
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# +4
# -4
# +10
# -10
# +12
# -12
# -6
# +6
# +4
# -4
# +8.5
# -8.5
# -5.5
# +5.5
# -1.5
# +1.5
# -11
# +11
# +3.5
# -3.5
# +10.5
# -10.5
# +1.5
# -1.5
# +1.5
# -1.5
# +12.5
# -12.5
# +3.5
# -3.5
# -2.5
# +2.5
# -6
# +6
# +3
# -3
# +2.5
# -2.5
# +1
# -1
# +5.5
# -5.5
# +4
# -4
# +9
# -9
# -5.5
# +5.5
# +8
# -8
# -1
# +1
# -5
# +5
# +2.5
# -2.5
# +4.5
# -4.5
# +1.5
# -1.5
# -2.5
# +2.5
# -11
# +11
# +4
# DEff            2460 non-null float64
# Opp TSP         2460 non-null float64
# Opp TOV         2460 non-null float64
# Opp ORB         2460 non-null float64
# Opp FTR         2460 non-null float64
# Opp Poss        2460 non-null float64
# Opp OEff        2460 non-null float64
# Opp DEff        2460 non-null float64
# Rolling3EFG     2370 non-null float64
# Rolling3TOV     2370 non-null float64
# Rolling3ORB     2370 non-null float64
# Rolling3FTR     2370 non-null float64
# Rolling3Pace    2370 non-null float64
# Rolling3OEff    2370 non-null float64
# Rolling3DEff    2370 non-null float64
# Opp R3EFG       2370 non-null float64
# Opp R3TOV       2370 non-null float64
# Opp R3ORB       2370 non-null float64
# Opp R3FTR       2370 non-null float64
# Opp R3Pace      2370 non-null float64
# Opp R3 OEff     2370 non-null float64
# Opp R3 DEff     2370 non-null float64
# Rolling9EFG     2190 non-null float64
# Rolling9TOV     2190 non-null float64
# Rolling9ORB     2190 non-null float64
# Rolling9FTR     2190 non-null float64
# Rolling9Pace    2190 non-null float64
# Rolling9OEff    2190 non-null float64
# Rolling9DEff    2190 non-null float64
# Opp R9EFG       2190 non-null float64
# Opp R9TOV       2190 non-null float64
# Opp R9ORB       2190 non-null float64
# Opp R9FTR       2190 non-null float64
# Opp R9Pace      2190 non-null float64
# Opp R9 OEff     2190 non-null float64
# Opp R9 DEff     2190 non-null float64
# Odds            2434 non-null float64
# Line            2434 non-null float64
# Cover           2460 non-null float64
# dtypes: float64(45), int64(6), object(2)
# memory usage: 1018.7+ KB

# %%
#spreaddb['Date'].apply(lambda x: int(x))
#moneydb['Date'].apply(lambda x: int(x))
moneydb['ML Odds'] = moneydb['ML Odds'].apply(lambda x: int(x))

# %%
for i, date in enumerate(db['Date']):
    
    mmask = (moneydb['Date'] == date) & (moneydb['Team'] == db['Team'][i])
    smask = (spreaddb['Date'] == date) & (spreaddb['Team'] == db['Team'][i])
    
    if mmask.any():
        print(moneydb[mmask]['ML Odds'])
        db['Odds'][i] = moneydb[mmask]['ML Odds']
    else:
        db['Odds'][i] = np.nan
        
    if smask.any():
        db['Line'][i] = spreaddb[smask]['Spread']
    else:
        db['Line'][i] = np.nan
# Out:
# 3   -1000
# Name: ML Odds, dtype: int64
# 12    155
# Name: ML Odds, dtype: int64
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# 34   -140
# Name: ML Odds, dtype: int64
# 56   -200
# Name: ML Odds, dtype: int64
# 82   -185
# Name: ML Odds, dtype: int64
# 85   -245
# Name: ML Odds, dtype: int64
# 102   -220
# Name: ML Odds, dtype: int64
# 119   -310
# Name: ML Odds, dtype: int64
# 135   -1000
# Name: ML Odds, dtype: int64
# 155   -140
# Name: ML Odds, dtype: int64
# 182   -125
# Name: ML Odds, dtype: int64
# 203   -165
# Name: ML Odds, dtype: int64
# 217   -450
# Name: ML Odds, dtype: int64
# 233   -280
# Name: ML Odds, dtype: int64
# 261   -475
# Name: ML Odds, dtype: int64
# 269   -700
# Name: ML Odds, dtype: int64
# 288   -380
# Name: ML Odds, dtype: int64
# 302    155
# Name: ML Odds, dtype: int64
# 322   -355
# Name: ML Odds, dtype: int64
# 333   -265
# Name: ML Odds, dtype: int64
# 348    120
# Name: ML Odds, dtype: int64
# 368    115
# Name: ML Odds, dtype: int64
# 377   -620
# Name: ML Odds, dtype: int64
# 393   -230
# Name: ML Odds, dtype: int64
# 421   -1000
# Name: ML Odds, dtype: int64
# 435   -170
# Name: ML Odds, dtype: int64
# 457   -1400
# Name: ML Odds, dtype: int64
# 476   -235
# Name: ML Odds, dtype: int64
# 484   -185
# Name: ML Odds, dtype: int64
# 505   -475
# Name: ML Odds, dtype: int64
# 518    135
# Name: ML Odds, dtype: int64
# 543   -230
# Name: ML Odds, dtype: int64
# 550   -130
# Name: ML Odds, dtype: int64
# 573    260
# Name: ML Odds, dtype: int64
# 584   -185
# Name: ML Odds, dtype: int64
# 607    255
# Name: ML Odds, dtype: int64
# 650    650
# Name: ML Odds, dtype: int64
# 660    145
# Name: ML Odds, dtype: int64
# 670    160
# Name: ML Odds, dtype: int64
# 682   -250
# Name: ML Odds, dtype: int64
# 708    328
# Name: ML Odds, dtype: int64
# 727   -170
# Name: ML Odds, dtype: int64
# 735   -700
# Name: ML Odds, dtype: int64
# 767   -550
# Name: ML Odds, dtype: int64
# 783   -165
# Name: ML Odds, dtype: int64
# 804   -320
# Name: ML Odds, dtype: int64
# 817   -215
# Name: ML Odds, dtype: int64
# 845   -340
# Name: ML Odds, dtype: int64
# 864   -550
# Name: ML Odds, dtype: int64
# 877   -3000
# Name: ML Odds, dtype: int64
# 895   -200
# Name: ML Odds, dtype: int64
# 902   -255
# Name: ML Odds, dtype: int64
# 927   -1800
# Name: ML Odds, dtype: int64
# 955   -800
# Name: ML Odds, dtype: int64
# 966   -118
# Name: ML Odds, dtype: int64
# 978   -155
# Name: ML Odds, dtype: int64
# 994   -2000
# Name: ML Odds, dtype: int64
# 1014   -290
# Name: ML Odds, dtype: int64
# 1021   -165
# Name: ML Odds, dtype: int64
# 1026   -150
# Name: ML Odds, dtype: int64
# 1054   -105
# Name: ML Odds, dtype: int64
# 1071   -900
# Name: ML Odds, dtype: int64
# 1088   -190
# Name: ML Odds, dtype: int64
# 1116   -120
# Name: ML Odds, dtype: int64
# 1139   -650
# Name: ML Odds, dtype: int64
# 1152   -175
# Name: ML Odds, dtype: int64
# 1164   -117
# Name: ML Odds, dtype: int64
# 1172   -600
# Name: ML Odds, dtype: int64
# 1194   -200
# Name: ML Odds, dtype: int64
# 1205   -900
# Name: ML Odds, dtype: int64
# 1235   -800
# Name: ML Odds, dtype: int64
# 1254   -380
# Name: ML Odds, dtype: int64
# 1284   -135
# Name: ML Odds, dtype: int64
# 1306   -440
# Name: ML Odds, dtype: int64
# 1331   -3250
# Name: ML Odds, dtype: int64
# 1343   -1250
# Name: ML Odds, dtype: int64
# 1351   -380
# Name: ML Odds, dtype: int64
# 1374   -300
# Name: ML Odds, dtype: int64
# 1397   -145
# Name: ML Odds, dtype: int64
# 1414    175
# Name: ML Odds, dtype: int64
# 1435   -280
# Name: ML Odds, dtype: int64
# 1467   -385
# Name: ML Odds, dtype: int64
# 1487    110
# Name: ML Odds, dtype: int64
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 1512    460
# Name: ML Odds, dtype: int64
# 43   -117
# Name: ML Odds, dtype: int64
# 69   -175
# Name: ML Odds, dtype: int64
# 1526    415
# Name: ML Odds, dtype: int64
# 1539   -220
# Name: ML Odds, dtype: int64
# 103    180
# Name: ML Odds, dtype: int64
# 143    105
# Name: ML Odds, dtype: int64
# 158   -250
# Name: ML Odds, dtype: int64
# 184    255
# Name: ML Odds, dtype: int64
# 1553    190
# Name: ML Odds, dtype: int64
# 1563    140
# Name: ML Odds, dtype: int64
# 1587    290
# Name: ML Odds, dtype: int64
# 270    240
# Name: ML Odds, dtype: int64
# 1607   -185
# Name: ML Odds, dtype: int64
# 305   -165
# Name: ML Odds, dtype: int64
# 1623    155
# Name: ML Odds, dtype: int64
# 318    385
# Name: ML Odds, dtype: int64
# 1640    120
# Name: ML Odds, dtype: int64
# 357   -300
# Name: ML Odds, dtype: int64
# 378   -185
# Name: ML Odds, dtype: int64
# 401   -165
# Name: ML Odds, dtype: int64
# 417   -260
# Name: ML Odds, dtype: int64
# 438    110
# Name: ML Odds, dtype: int64
# 450    130
# Name: ML Odds, dtype: int64
# 483   -130
# Name: ML Odds, dtype: int64
# 1660    460
# Name: ML Odds, dtype: int64
# 537    110
# Name: ML Odds, dtype: int64
# 557    210
# Name: ML Odds, dtype: int64
# 1682    550
# Name: ML Odds, dtype: int64
# 589   -230
# Name: ML Odds, dtype: int64
# 614    170
# Name: ML Odds, dtype: int64
# 632    155
# Name: ML Odds, dtype: int64
# 1698    650
# Name: ML Odds, dtype: int64
# 1713    175
# Name: ML Odds, dtype: int64
# 1729    260
# Name: ML Odds, dtype: int64
# 695    175
# Name: ML Odds, dtype: int64
# 716    650
# Name: ML Odds, dtype: int64
# 1742    240
# Name: ML Odds, dtype: int64
# 776    390
# Name: ML Odds, dtype: int64
# 798    2500
# Name: ML Odds, dtype: int64
# 1752    315
# Name: ML Odds, dtype: int64
# 822   -185
# Name: ML Odds, dtype: int64
# 843    210
# Name: ML Odds, dtype: int64
# 1761   -165
# Name: ML Odds, dtype: int64
# 1766    100
# Name: ML Odds, dtype: int64
# 1781   -145
# Name: ML Odds, dtype: int64
# 913   -290
# Name: ML Odds, dtype: int64
# 1806    195
# Name: ML Odds, dtype: int64
# 949    270
# Name: ML Odds, dtype: int64
# 988    145
# Name: ML Odds, dtype: int64
# 1010   -135
# Name: ML Odds, dtype: int64
# 1820    295
# Name: ML Odds, dtype: int64
# 1829   -1100
# Name: ML Odds, dtype: int64
# 1035   -135
# Name: ML Odds, dtype: int64
# 1059    350
# Name: ML Odds, dtype: int64
# 1070    600
# Name: ML Odds, dtype: int64
# 1087   -120
# Name: ML Odds, dtype: int64
# 1124    245
# Name: ML Odds, dtype: int64
# 1856   -118
# Name: ML Odds, dtype: int64
# 1866    130
# Name: ML Odds, dtype: int64
# 1885    160
# Name: ML Odds, dtype: int64
# 1905   -220
# Name: ML Odds, dtype: int64
# 1918    280
# Name: ML Odds, dtype: int64
# 1189   -500
# Name: ML Odds, dtype: int64
# 1218    245
# Name: ML Odds, dtype: int64
# 1242    400
# Name: ML Odds, dtype: int64
# 1263   -220
# Name: ML Odds, dtype: int64
# 1934    155
# Name: ML Odds, dtype: int64
# 1283   -210
# Name: ML Odds, dtype: int64
# 1310   -550
# Name: ML Odds, dtype: int64
# 1333    180
# Name: ML Odds, dtype: int64
# 1942    155
# Name: ML Odds, dtype: int64
# 1963   -165
# Name: ML Odds, dtype: int64
# 1987   -220
# Name: ML Odds, dtype: int64
# 2004    135
# Name: ML Odds, dtype: int64
# 1368    100
# Name: ML Odds, dtype: int64
# 1396    135
# Name: ML Odds, dtype: int64
# 1415   -210
# Name: ML Odds, dtype: int64
# 2021   -135
# Name: ML Odds, dtype: int64
# 1470    220
# Name: ML Odds, dtype: int64
# 1490    165
# Name: ML Odds, dtype: int64
# 0   -155
# Name: ML Odds, dtype: int64
# 26    105
# Name: ML Odds, dtype: int64
# 49   -485
# Name: ML Odds, dtype: int64
# 74    155
# Name: ML Odds, dtype: int64
# 1520   -165
# Name: ML Odds, dtype: int64
# 1535   -245
# Name: ML Odds, dtype: int64
# 115   -485
# Name: ML Odds, dtype: int64
# 153    130
# Name: ML Odds, dtype: int64
# 183    105
# Name: ML Odds, dtype: int64
# 212   -150
# Name: ML Odds, dtype: int64
# 2027   -200
# Name: ML Odds, dtype: int64
# 232    240
# Name: ML Odds, dtype: int64
# 257   -185
# Name: ML Odds, dtype: int64
# 2037   -200
# Name: ML Odds, dtype: int64
# 1605   -380
# Name: ML Odds, dtype: int64
# 295   -185
# Name: ML Odds, dtype: int64
# 1622   -175
# Name: ML Odds, dtype: int64
# 319   -485
# Name: ML Odds, dtype: int64
# 1638   -185
# Name: ML Odds, dtype: int64
# 355    120
# Name: ML Odds, dtype: int64
# 2045   -900
# Name: ML Odds, dtype: int64
# 2059   -1200
# Name: ML Odds, dtype: int64
# 422   -200
# Name: ML Odds, dtype: int64
# 443   -280
# Name: ML Odds, dtype: int64
# 453   -165
# Name: ML Odds, dtype: int64
# 472   -230
# Name: ML Odds, dtype: int64
# 1661   -620
# Name: ML Odds, dtype: int64
# 2078    155
# Name: ML Odds, dtype: int64
# 526    170
# Name: ML Odds, dtype: int64
# 560    280
# Name: ML Odds, dtype: int64
# 1684    195
# Name: ML Odds, dtype: int64
# 594    130
# Name: ML Odds, dtype: int64
# 613   -1650
# Name: ML Odds, dtype: int64
# 639   -120
# Name: ML Odds, dtype: int64
# 654    160
# Name: ML Odds, dtype: int64
# 669   -125
# Name: ML Odds, dtype: int64
# 1730    210
# Name: ML Odds, dtype: int64
# 687   -550
# Name: ML Odds, dtype: int64
# 2088   -185
# Name: ML Odds, dtype: int64
# 713   -2150
# Name: ML Odds, dtype: int64
# 751   -130
# Name: ML Odds, dtype: int64
# 2106   -175
# Name: ML Odds, dtype: int64
# 796   -117
# Name: ML Odds, dtype: int64
# 810   -390
# Name: ML Odds, dtype: int64
# 834    195
# Name: ML Odds, dtype: int64
# 855   -175
# Name: ML Odds, dtype: int64
# 879   -305
# Name: ML Odds, dtype: int64
# 1778    180
# Name: ML Odds, dtype: int64
# 892    105
# Name: ML Odds, dtype: int64
# 1799   -240
# Name: ML Odds, dtype: int64
# 2109   -550
# Name: ML Odds, dtype: int64
# 944    170
# Name: ML Odds, dtype: int64
# 979    135
# Name: ML Odds, dtype: int64
# 998   -120
# Name: ML Odds, dtype: int64
# 1013    170
# Name: ML Odds, dtype: int64
# 1832    115
# Name: ML Odds, dtype: int64
# 1024   -440
# Name: ML Odds, dtype: int64
# 2127   -165
# Name: ML Odds, dtype: int64
# 1078   -117
# Name: ML Odds, dtype: int64
# 1142    160
# Name: ML Odds, dtype: int64
# 1864    115
# Name: ML Odds, dtype: int64
# 1161   -125
# Name: ML Odds, dtype: int64
# 1921   -400
# Name: ML Odds, dtype: int64
# 1187   -135
# Name: ML Odds, dtype: int64
# 1224    145
# Name: ML Odds, dtype: int64
# 1248    210
# Name: ML Odds, dtype: int64
# 1260   -165
# Name: ML Odds, dtype: int64
# 1940    600
# Name: ML Odds, dtype: int64
# 1277   -165
# Name: ML Odds, dtype: int64
# 1303   -165
# Name: ML Odds, dtype: int64
# 1325    125
# Name: ML Odds, dtype: int64
# 1959   -800
# Name: ML Odds, dtype: int64
# 1981   -2000
# Name: ML Odds, dtype: int64
# 2008    260
# Name: ML Odds, dtype: int64
# 1362   -330
# Name: ML Odds, dtype: int64
# 1398    165
# Name: ML Odds, dtype: int64
# 1421   -130
# Name: ML Odds, dtype: int64
# 2022    380
# Name: ML Odds, dtype: int64
# 1466    345
# Name: ML Odds, dtype: int64
# 1483   -400
# Name: ML Odds, dtype: int64
# 2144    155
# Name: ML Odds, dtype: int64
# 32    140
# Name: ML Odds, dtype: int64
# 41   -140
# Name: ML Odds, dtype: int64
# 63   -125
# Name: ML Odds, dtype: int64
# 2162   -165
# Name: ML Odds, dtype: int64
# 2172    280
# Name: ML Odds, dtype: int64
# 110    170
# Name: ML Odds, dtype: int64
# 130    500
# Name: ML Odds, dtype: int64
# 137    120
# Name: ML Odds, dtype: int64
# 160    120
# Name: ML Odds, dtype: int64
# 177   -175
# Name: ML Odds, dtype: int64
# 1554    105
# Name: ML Odds, dtype: int64
# 221    175
# Name: ML Odds, dtype: int64
# 237    240
# Name: ML Odds, dtype: int64
# 1565    350
# Name: ML Odds, dtype: int64
# 262    180
# Name: ML Odds, dtype: int64
# 1603    140
# Name: ML Odds, dtype: int64
# 299   -185
# Name: ML Odds, dtype: int64
# 1641   -140
# Name: ML Odds, dtype: int64
# 364    460
# Name: ML Odds, dtype: int64
# 2183   -150
# Name: ML Odds, dtype: int64
# 376    460
# Name: ML Odds, dtype: int64
# 395    105
# Name: ML Odds, dtype: int64
# 414   -185
# Name: ML Odds, dtype: int64
# 2197   -185
# Name: ML Odds, dtype: int64
# 2207   -130
# Name: ML Odds, dtype: int64
# 466    210
# Name: ML Odds, dtype: int64
# 494    220
# Name: ML Odds, dtype: int64
# 1659   -250
# Name: ML Odds, dtype: int64
# 2073   -165
# Name: ML Odds, dtype: int64
# 546    675
# Name: ML Odds, dtype: int64
# 551    110
# Name: ML Odds, dtype: int64
# 1676    158
# Name: ML Odds, dtype: int64
# 588    190
# Name: ML Odds, dtype: int64
# 609    155
# Name: ML Odds, dtype: int64
# 2220    700
# Name: ML Odds, dtype: int64
# 1692   -320
# Name: ML Odds, dtype: int64
# 1721    160
# Name: ML Odds, dtype: int64
# 2083   -125
# Name: ML Odds, dtype: int64
# 711   -260
# Name: ML Odds, dtype: int64
# 737   -230
# Name: ML Odds, dtype: int64
# 766    425
# Name: ML Odds, dtype: int64
# 2099   -470
# Name: ML Odds, dtype: int64
# 830    925
# Name: ML Odds, dtype: int64
# 872    210
# Name: ML Odds, dtype: int64
# 878    275
# Name: ML Odds, dtype: int64
# 893   -125
# Name: ML Odds, dtype: int64
# 1802   -310
# Name: ML Odds, dtype: int64
# 931   -135
# Name: ML Odds, dtype: int64
# 2227   -135
# Name: ML Odds, dtype: int64
# 2237    190
# Name: ML Odds, dtype: int64
# 1006    450
# Name: ML Odds, dtype: int64
# 1840    265
# Name: ML Odds, dtype: int64
# 1034    115
# Name: ML Odds, dtype: int64
# 1056   -125
# Name: ML Odds, dtype: int64
# 1069   -380
# Name: ML Odds, dtype: int64
# 1090    180
# Name: ML Odds, dtype: int64
# 1109   -105
# Name: ML Odds, dtype: int64
# 1858    100
# Name: ML Odds, dtype: int64
# 1865   -135
# Name: ML Odds, dtype: int64
# 1883   -360
# Name: ML Odds, dtype: int64
# 1901   -103
# Name: ML Odds, dtype: int64
# 1198    170
# Name: ML Odds, dtype: int64
# 2254    475
# Name: ML Odds, dtype: int64
# 1244   -150
# Name: ML Odds, dtype: int64
# 1266   -175
# Name: ML Odds, dtype: int64
# 1936    180
# Name: ML Odds, dtype: int64
# 1273   -165
# Name: ML Odds, dtype: int64
# 1302    145
# Name: ML Odds, dtype: int64
# 2257    135
# Name: ML Odds, dtype: int64
# 1943   -175
# Name: ML Odds, dtype: int64
# 1957   -185
# Name: ML Odds, dtype: int64
# 1982    180
# Name: ML Odds, dtype: int64
# 2001   -330
# Name: ML Odds, dtype: int64
# 2266    135
# Name: ML Odds, dtype: int64
# 1367    135
# Name: ML Odds, dtype: int64
# 1394    450
# Name: ML Odds, dtype: int64
# 1416    270
# Name: ML Odds, dtype: int64
# 1431    475
# Name: ML Odds, dtype: int64
# 1454    500
# Name: ML Odds, dtype: int64
# 1494    290
# Name: ML Odds, dtype: int64
# 5   -165
# Name: ML Odds, dtype: int64
# 44    180
# Name: ML Odds, dtype: int64
# 64   -140
# Name: ML Odds, dtype: int64
# 1524    270
# Name: ML Odds, dtype: int64
# 1551    230
# Name: ML Odds, dtype: int64
# 104    255
# Name: ML Odds, dtype: int64
# 124    650
# Name: ML Odds, dtype: int64
# 169   -115
# Name: ML Odds, dtype: int64
# 187    325
# Name: ML Odds, dtype: int64
# 207    325
# Name: ML Odds, dtype: int64
# 245    108
# Name: ML Odds, dtype: int64
# 1584    200
# Name: ML Odds, dtype: int64
# 1598    775
# Name: ML Odds, dtype: int64
# 2042    1100
# Name: ML Odds, dtype: int64
# 1617   -320
# Name: ML Odds, dtype: int64
# 309    240
# Name: ML Odds, dtype: int64
# 2284    650
# Name: ML Odds, dtype: int64
# 327    700
# Name: ML Odds, dtype: int64
# 1647    500
# Name: ML Odds, dtype: int64
# 367    385
# Name: ML Odds, dtype: int64
# 2051    130
# Name: ML Odds, dtype: int64
# 2058    775
# Name: ML Odds, dtype: int64
# 416    220
# Name: ML Odds, dtype: int64
# 447    120
# Name: ML Odds, dtype: int64
# 456    1100
# Name: ML Odds, dtype: int64
# 498    550
# Name: ML Odds, dtype: int64
# 1674    1750
# Name: ML Odds, dtype: int64
# 528    275
# Name: ML Odds, dtype: int64
# 2293   -103
# Name: ML Odds, dtype: int64
# 1679    110
# Name: ML Odds, dtype: int64
# 591    145
# Name: ML Odds, dtype: int64
# 625    350
# Name: ML Odds, dtype: int64
# 644    360
# Name: ML Odds, dtype: int64
# 1707    450
# Name: ML Odds, dtype: int64
# 664    510
# Name: ML Odds, dtype: int64
# 702    950
# Name: ML Odds, dtype: int64
# 2092    600
# Name: ML Odds, dtype: int64
# 710    220
# Name: ML Odds, dtype: int64
# 747    328
# Name: ML Odds, dtype: int64
# 771    255
# Name: ML Odds, dtype: int64
# 788    2750
# Name: ML Odds, dtype: int64
# 1746    1250
# Name: ML Odds, dtype: int64
# 823    160
# Name: ML Odds, dtype: int64
# 836   -145
# Name: ML Odds, dtype: int64
# 865    425
# Name: ML Odds, dtype: int64
# 888    575
# Name: ML Odds, dtype: int64
# 1785   -125
# Name: ML Odds, dtype: int64
# 919    315
# Name: ML Odds, dtype: int64
# 932    210
# Name: ML Odds, dtype: int64
# 2117    195
# Name: ML Odds, dtype: int64
# 959    400
# Name: ML Odds, dtype: int64
# 981   -145
# Name: ML Odds, dtype: int64
# 1816    400
# Name: ML Odds, dtype: int64
# 1833   -135
# Name: ML Odds, dtype: int64
# 1042    210
# Name: ML Odds, dtype: int64
# 2133    170
# Name: ML Odds, dtype: int64
# 2301    175
# Name: ML Odds, dtype: int64
# 1093   -230
# Name: ML Odds, dtype: int64
# 1141    155
# Name: ML Odds, dtype: int64
# 1878    310
# Name: ML Odds, dtype: int64
# 1894    185
# Name: ML Odds, dtype: int64
# 1908    550
# Name: ML Odds, dtype: int64
# 1178    1000
# Name: ML Odds, dtype: int64
# 1191    105
# Name: ML Odds, dtype: int64
# 1208    568
# Name: ML Odds, dtype: int64
# 2304   -102
# Name: ML Odds, dtype: int64
# 1267    155
# Name: ML Odds, dtype: int64
# 1938    700
# Name: ML Odds, dtype: int64
# 1289   -130
# Name: ML Odds, dtype: int64
# 1314    800
# Name: ML Odds, dtype: int64
# 1328    700
# Name: ML Odds, dtype: int64
# 1951    170
# Name: ML Odds, dtype: int64
# 1969    350
# Name: ML Odds, dtype: int64
# 1991    135
# Name: ML Odds, dtype: int64
# 2274    450
# Name: ML Odds, dtype: int64
# 1386    2500
# Name: ML Odds, dtype: int64
# 1410    180
# Name: ML Odds, dtype: int64
# 2322    4500
# Name: ML Odds, dtype: int64
# 1443    700
# Name: ML Odds, dtype: int64
# 1457    1000
# Name: ML Odds, dtype: int64
# 2324    170
# Name: ML Odds, dtype: int64
# 7   -750
# Name: ML Odds, dtype: int64
# 1513   -620
# Name: ML Odds, dtype: int64
# 2332    120
# Name: ML Odds, dtype: int64
# 80   -140
# Name: ML Odds, dtype: int64
# 2157   -360
# Name: ML Odds, dtype: int64
# 2171   -270
# Name: ML Odds, dtype: int64
# 2339   -1200
# Name: ML Odds, dtype: int64
# 125   -1000
# Name: ML Odds, dtype: int64
# 136   -140
# Name: ML Odds, dtype: int64
# 152   -150
# Name: ML Odds, dtype: int64
# 191   -550
# Name: ML Odds, dtype: int64
# 208   -140
# Name: ML Odds, dtype: int64
# 227   -1100
# Name: ML Odds, dtype: int64
# 243   -925
# Name: ML Odds, dtype: int64
# 1568    155
# Name: ML Odds, dtype: int64
# 258   -1000
# Name: ML Odds, dtype: int64
# 278    120
# Name: ML Odds, dtype: int64
# 1612   -185
# Name: ML Odds, dtype: int64
# 311   -230
# Name: ML Odds, dtype: int64
# 1631   -485
# Name: ML Odds, dtype: int64
# 336    135
# Name: ML Odds, dtype: int64
# 1649   -280
# Name: ML Odds, dtype: int64
# 2177   -125
# Name: ML Odds, dtype: int64
# 2062   -330
# Name: ML Odds, dtype: int64
# 398   -290
# Name: ML Odds, dtype: int64
# 2201   -650
# Name: ML Odds, dtype: int64
# 2215   -185
# Name: ML Odds, dtype: int64
# 468    110
# Name: ML Odds, dtype: int64
# 497   -1100
# Name: ML Odds, dtype: int64
# 509   -155
# Name: ML Odds, dtype: int64
# 527   -200
# Name: ML Odds, dtype: int64
# 556   -250
# Name: ML Odds, dtype: int64
# 572   -320
# Name: ML Odds, dtype: int64
# 586   -260
# Name: ML Odds, dtype: int64
# 621   -485
# Name: ML Odds, dtype: int64
# 1694    130
# Name: ML Odds, dtype: int64
# 674   -210
# Name: ML Odds, dtype: int64
# 1732    110
# Name: ML Odds, dtype: int64
# 699   -370
# Name: ML Odds, dtype: int64
# 720    125
# Name: ML Odds, dtype: int64
# 746   -365
# Name: ML Odds, dtype: int64
# 769   -280
# Name: ML Odds, dtype: int64
# 786   -145
# Name: ML Odds, dtype: int64
# 809   -225
# Name: ML Odds, dtype: int64
# 826    165
# Name: ML Odds, dtype: int64
# 848   -500
# Name: ML Odds, dtype: int64
# 856   -380
# Name: ML Odds, dtype: int64
# 889   -850
# Name: ML Odds, dtype: int64
# 1794    425
# Name: ML Odds, dtype: int64
# 896   -130
# Name: ML Odds, dtype: int64
# 1805   -145
# Name: ML Odds, dtype: int64
# 2123   -450
# Name: ML Odds, dtype: int64
# 961   -165
# Name: ML Odds, dtype: int64
# 2342    180
# Name: ML Odds, dtype: int64
# 985   -130
# Name: ML Odds, dtype: int64
# 1007   -600
# Name: ML Odds, dtype: int64
# 1019   -175
# Name: ML Odds, dtype: int64
# 1830    245
# Name: ML Odds, dtype: int64
# 2135   -450
# Name: ML Odds, dtype: int64
# 2303   -395
# Name: ML Odds, dtype: int64
# 2348    120
# Name: ML Odds, dtype: int64
# 1128    465
# Name: ML Odds, dtype: int64
# 1862   -290
# Name: ML Odds, dtype: int64
# 1153    155
# Name: ML Odds, dtype: int64
# 1911   -145
# Name: ML Odds, dtype: int64
# 1197   -155
# Name: ML Odds, dtype: int64
# 1217   -900
# Name: ML Odds, dtype: int64
# 1241   -165
# Name: ML Odds, dtype: int64
# 1268   -165
# Name: ML Odds, dtype: int64
# 2357    135
# Name: ML Odds, dtype: int64
# 1318    350
# Name: ML Odds, dtype: int64
# 1336    100
# Name: ML Odds, dtype: int64
# 1970    135
# Name: ML Odds, dtype: int64
# 1345   -135
# Name: ML Odds, dtype: int64
# 2013    165
# Name: ML Odds, dtype: int64
# 1385   -440
# Name: ML Odds, dtype: int64
# 1406    160
# Name: ML Odds, dtype: int64
# 1428   -200
# Name: ML Odds, dtype: int64
# 1446    525
# Name: ML Odds, dtype: int64
# 1461   -330
# Name: ML Odds, dtype: int64
# 1482    325
# Name: ML Odds, dtype: int64
# 15   -485
# Name: ML Odds, dtype: int64
# 22    155
# Name: ML Odds, dtype: int64
# 51    205
# Name: ML Odds, dtype: int64
# 72    160
# Name: ML Odds, dtype: int64
# 1531    180
# Name: ML Odds, dtype: int64
# 2169   -150
# Name: ML Odds, dtype: int64
# 94    130
# Name: ML Odds, dtype: int64
# 2364    170
# Name: ML Odds, dtype: int64
# 2373   -165
# Name: ML Odds, dtype: int64
# 164    260
# Name: ML Odds, dtype: int64
# 180    385
# Name: ML Odds, dtype: int64
# 213    130
# Name: ML Odds, dtype: int64
# 2031   -155
# Name: ML Odds, dtype: int64
# 244   -118
# Name: ML Odds, dtype: int64
# 1570    140
# Name: ML Odds, dtype: int64
# 265   -130
# Name: ML Odds, dtype: int64
# 268    500
# Name: ML Odds, dtype: int64
# 1613    170
# Name: ML Odds, dtype: int64
# 313   -130
# Name: ML Odds, dtype: int64
# 1630    385
# Name: ML Odds, dtype: int64
# 340    480
# Name: ML Odds, dtype: int64
# 2187    175
# Name: ML Odds, dtype: int64
# 386    160
# Name: ML Odds, dtype: int64
# 406    385
# Name: ML Odds, dtype: int64
# 2382    200
# Name: ML Odds, dtype: int64
# 2204    500
# Name: ML Odds, dtype: int64
# 467   -250
# Name: ML Odds, dtype: int64
# 488    350
# Name: ML Odds, dtype: int64
# 1669    160
# Name: ML Odds, dtype: int64
# 2072    145
# Name: ML Odds, dtype: int64
# 542    210
# Name: ML Odds, dtype: int64
# 563   -125
# Name: ML Odds, dtype: int64
# 578   -250
# Name: ML Odds, dtype: int64
# 2387    160
# Name: ML Odds, dtype: int64
# 610   -260
# Name: ML Odds, dtype: int64
# 645   -450
# Name: ML Odds, dtype: int64
# 1702    290
# Name: ML Odds, dtype: int64
# 679   -250
# Name: ML Odds, dtype: int64
# 729    100
# Name: ML Odds, dtype: int64
# 1739   -320
# Name: ML Odds, dtype: int64
# 2101    105
# Name: ML Odds, dtype: int64
# 794    600
# Name: ML Odds, dtype: int64
# 806    155
# Name: ML Odds, dtype: int64
# 2390   -175
# Name: ML Odds, dtype: int64
# 869    110
# Name: ML Odds, dtype: int64
# 880    245
# Name: ML Odds, dtype: int64
# 1787   -380
# Name: ML Odds, dtype: int64
# 914    195
# Name: ML Odds, dtype: int64
# 1807   -235
# Name: ML Odds, dtype: int64
# 2121   -185
# Name: ML Odds, dtype: int64
# 953   -475
# Name: ML Odds, dtype: int64
# 983   -335
# Name: ML Odds, dtype: int64
# 997    155
# Name: ML Odds, dtype: int64
# 1814    270
# Name: ML Odds, dtype: int64
# 1837   -650
# Name: ML Odds, dtype: int64
# 1048   -220
# Name: ML Odds, dtype: int64
# 2136    145
# Name: ML Odds, dtype: int64
# 1080   -220
# Name: ML Odds, dtype: int64
# 1106    1050
# Name: ML Odds, dtype: int64
# 1143   -185
# Name: ML Odds, dtype: int64
# 1873   -135
# Name: ML Odds, dtype: int64
# 1889   -330
# Name: ML Odds, dtype: int64
# 1158    290
# Name: ML Odds, dtype: int64
# 1924    240
# Name: ML Odds, dtype: int64
# 2250    250
# Name: ML Odds, dtype: int64
# 1213    170
# Name: ML Odds, dtype: int64
# 1232    135
# Name: ML Odds, dtype: int64
# 1255    315
# Name: ML Odds, dtype: int64
# 2355    105
# Name: ML Odds, dtype: int64
# 2399   -125
# Name: ML Odds, dtype: int64
# 2261    170
# Name: ML Odds, dtype: int64
# 1948    270
# Name: ML Odds, dtype: int64
# 1967    170
# Name: ML Odds, dtype: int64
# 1986    200
# Name: ML Odds, dtype: int64
# 2011   -400
# Name: ML Odds, dtype: int64
# 1375    250
# Name: ML Odds, dtype: int64
# 1392   -440
# Name: ML Odds, dtype: int64
# 1413    100
# Name: ML Odds, dtype: int64
# 1432   -130
# Name: ML Odds, dtype: int64
# 1471   -240
# Name: ML Odds, dtype: int64
# 1484    250
# Name: ML Odds, dtype: int64
# 14    385
# Name: ML Odds, dtype: int64
# 1507    465
# Name: ML Odds, dtype: int64
# 39    130
# Name: ML Odds, dtype: int64
# 67    475
# Name: ML Odds, dtype: int64
# 2154    775
# Name: ML Odds, dtype: int64
# 2338    775
# Name: ML Odds, dtype: int64
# 106    2500
# Name: ML Odds, dtype: int64
# 146    1500
# Name: ML Odds, dtype: int64
# 159    210
# Name: ML Odds, dtype: int64
# 175    425
# Name: ML Odds, dtype: int64
# 204    650
# Name: ML Odds, dtype: int64
# 219    700
# Name: ML Odds, dtype: int64
# 231    315
# Name: ML Odds, dtype: int64
# 259    650
# Name: ML Odds, dtype: int64
# 2039    850
# Name: ML Odds, dtype: int64
# 1616    260
# Name: ML Odds, dtype: int64
# 297    700
# Name: ML Odds, dtype: int64
# 2278    400
# Name: ML Odds, dtype: int64
# 1642    700
# Name: ML Odds, dtype: int64
# 362    265
# Name: ML Odds, dtype: int64
# 2185    500
# Name: ML Odds, dtype: int64
# 379    160
# Name: ML Odds, dtype: int64
# 415    160
# Name: ML Odds, dtype: int64
# 440    350
# Name: ML Odds, dtype: int64
# 460    255
# Name: ML Odds, dtype: int64
# 500    1200
# Name: ML Odds, dtype: int64
# 1670    380
# Name: ML Odds, dtype: int64
# 534    1500
# Name: ML Odds, dtype: int64
# 564    1000
# Name: ML Odds, dtype: int64
# 1690    1800
# Name: ML Odds, dtype: int64
# 585    160
# Name: ML Odds, dtype: int64
# 611    220
# Name: ML Odds, dtype: int64
# 634    550
# Name: ML Odds, dtype: int64
# 1697    230
# Name: ML Odds, dtype: int64
# 667    550
# Name: ML Odds, dtype: int64
# 1724    1750
# Name: ML Odds, dtype: int64
# 685    270
# Name: ML Odds, dtype: int64
# 2084    775
# Name: ML Odds, dtype: int64
# 712    1300
# Name: ML Odds, dtype: int64
# 739   -125
# Name: ML Odds, dtype: int64
# 759    550
# Name: ML Odds, dtype: int64
# 2102    1750
# Name: ML Odds, dtype: int64
# 1750    925
# Name: ML Odds, dtype: int64
# 815    255
# Name: ML Odds, dtype: int64
# 837    125
# Name: ML Odds, dtype: int64
# 862    1750
# Name: ML Odds, dtype: int64
# 876    1500
# Name: ML Odds, dtype: int64
# 1765    290
# Name: ML Odds, dtype: int64
# 912    245
# Name: ML Odds, dtype: int64
# 1803    255
# Name: ML Odds, dtype: int64
# 2113    1350
# Name: ML Odds, dtype: int64
# 971    270
# Name: ML Odds, dtype: int64
# 1000    315
# Name: ML Odds, dtype: int64
# 1810    475
# Name: ML Odds, dtype: int64
# 1836    475
# Name: ML Odds, dtype: int64
# 1025    350
# Name: ML Odds, dtype: int64
# 1060    600
# Name: ML Odds, dtype: int64
# 2295    315
# Name: ML Odds, dtype: int64
# 1098    1350
# Name: ML Odds, dtype: int64
# 1115    210
# Name: ML Odds, dtype: int64
# 1135    450
# Name: ML Odds, dtype: int64
# 1881    180
# Name: ML Odds, dtype: int64
# 1903    155
# Name: ML Odds, dtype: int64
# 1923    185
# Name: ML Odds, dtype: int64
# 1188    400
# Name: ML Odds, dtype: int64
# 1207    105
# Name: ML Odds, dtype: int64
# 1227   -220
# Name: ML Odds, dtype: int64
# 1270    170
# Name: ML Odds, dtype: int64
# 2358    315
# Name: ML Odds, dtype: int64
# 1292    550
# Name: ML Odds, dtype: int64
# 1301    600
# Name: ML Odds, dtype: int64
# 1330    1625
# Name: ML Odds, dtype: int64
# 1945   -175
# Name: ML Odds, dtype: int64
# 1958    550
# Name: ML Odds, dtype: int64
# 2000    270
# Name: ML Odds, dtype: int64
# 1356   -120
# Name: ML Odds, dtype: int64
# 1363    270
# Name: ML Odds, dtype: int64
# 2316    1100
# Name: ML Odds, dtype: int64
# 1433    110
# Name: ML Odds, dtype: int64
# 1475   -145
# Name: ML Odds, dtype: int64
# 1501   -1000
# Name: ML Odds, dtype: int64
# 19    105
# Name: ML Odds, dtype: int64
# 36   -245
# Name: ML Odds, dtype: int64
# 55   -120
# Name: ML Odds, dtype: int64
# 79   -185
# Name: ML Odds, dtype: int64
# 2159   -102
# Name: ML Odds, dtype: int64
# 1549   -220
# Name: ML Odds, dtype: int64
# 111   -200
# Name: ML Odds, dtype: int64
# 132    230
# Name: ML Odds, dtype: int64
# 142   -125
# Name: ML Odds, dtype: int64
# 162   -140
# Name: ML Odds, dtype: int64
# 174   -550
# Name: ML Odds, dtype: int64
# 200   -120
# Name: ML Odds, dtype: int64
# 222    175
# Name: ML Odds, dtype: int64
# 253   -265
# Name: ML Odds, dtype: int64
# 1580   -102
# Name: ML Odds, dtype: int64
# 1597   -700
# Name: ML Odds, dtype: int64
# 283   -280
# Name: ML Odds, dtype: int64
# 310    190
# Name: ML Odds, dtype: int64
# 2280   -105
# Name: ML Odds, dtype: int64
# 330    290
# Name: ML Odds, dtype: int64
# 345   -200
# Name: ML Odds, dtype: int64
# 373   -550
# Name: ML Odds, dtype: int64
# 2052    240
# Name: ML Odds, dtype: int64
# 387   -185
# Name: ML Odds, dtype: int64
# 394   -115
# Name: ML Odds, dtype: int64
# 2192   -290
# Name: ML Odds, dtype: int64
# 442    240
# Name: ML Odds, dtype: int64
# 469   -130
# Name: ML Odds, dtype: int64
# 502   -125
# Name: ML Odds, dtype: int64
# 514   -220
# Name: ML Odds, dtype: int64
# 524    110
# Name: ML Odds, dtype: int64
# 548    255
# Name: ML Odds, dtype: int64
# 565   -1500
# Name: ML Odds, dtype: int64
# 581   -120
# Name: ML Odds, dtype: int64
# 2386   -185
# Name: ML Odds, dtype: int64
# 624   -440
# Name: ML Odds, dtype: int64
# 646    175
# Name: ML Odds, dtype: int64
# 658    190
# Name: ML Odds, dtype: int64
# 671   -185
# Name: ML Odds, dtype: int64
# 703   -1450
# Name: ML Odds, dtype: int64
# 731   -650
# Name: ML Odds, dtype: int64
# 753   -250
# Name: ML Odds, dtype: int64
# 775   -135
# Name: ML Odds, dtype: int64
# 791    135
# Name: ML Odds, dtype: int64
# 835   -235
# Name: ML Odds, dtype: int64
# 853   -230
# Name: ML Odds, dtype: int64
# 874    425
# Name: ML Odds, dtype: int64
# 891    125
# Name: ML Odds, dtype: int64
# 898    160
# Name: ML Odds, dtype: int64
# 921   -210
# Name: ML Odds, dtype: int64
# 940   -250
# Name: ML Odds, dtype: int64
# 2231   -135
# Name: ML Odds, dtype: int64
# 980    125
# Name: ML Odds, dtype: int64
# 2240    325
# Name: ML Odds, dtype: int64
# 1821   -325
# Name: ML Odds, dtype: int64
# 1842   -215
# Name: ML Odds, dtype: int64
# 1023    178
# Name: ML Odds, dtype: int64
# 2139   -113
# Name: ML Odds, dtype: int64
# 2296    140
# Name: ML Odds, dtype: int64
# 1084   -175
# Name: ML Odds, dtype: int64
# 1118    125
# Name: ML Odds, dtype: int64
# 1138    475
# Name: ML Odds, dtype: int64
# 1877    185
# Name: ML Odds, dtype: int64
# 1895   -200
# Name: ML Odds, dtype: int64
# 1915    170
# Name: ML Odds, dtype: int64
# 1181   -700
# Name: ML Odds, dtype: int64
# 2309    110
# Name: ML Odds, dtype: int64
# 2406    350
# Name: ML Odds, dtype: int64
# 1269    145
# Name: ML Odds, dtype: int64
# 1297   -380
# Name: ML Odds, dtype: int64
# 1323    100
# Name: ML Odds, dtype: int64
# 1341   -102
# Name: ML Odds, dtype: int64
# 1954    305
# Name: ML Odds, dtype: int64
# 1346    600
# Name: ML Odds, dtype: int64
# 2017   -125
# Name: ML Odds, dtype: int64
# 2268    350
# Name: ML Odds, dtype: int64
# 1384    350
# Name: ML Odds, dtype: int64
# 1400    400
# Name: ML Odds, dtype: int64
# 1426    1500
# Name: ML Odds, dtype: int64
# 2025    475
# Name: ML Odds, dtype: int64
# 2329    240
# Name: ML Odds, dtype: int64
# 1500    650
# Name: ML Odds, dtype: int64
# 21    550
# Name: ML Odds, dtype: int64
# 37    205
# Name: ML Odds, dtype: int64
# 2163    145
# Name: ML Odds, dtype: int64
# 2166    460
# Name: ML Odds, dtype: int64
# 1544    550
# Name: ML Odds, dtype: int64
# 113    280
# Name: ML Odds, dtype: int64
# 2369    320
# Name: ML Odds, dtype: int64
# 2370    425
# Name: ML Odds, dtype: int64
# 172    600
# Name: ML Odds, dtype: int64
# 190    425
# Name: ML Odds, dtype: int64
# 1561    110
# Name: ML Odds, dtype: int64
# 255    240
# Name: ML Odds, dtype: int64
# 1585   -220
# Name: ML Odds, dtype: int64
# 1601    240
# Name: ML Odds, dtype: int64
# 272    100
# Name: ML Odds, dtype: int64
# 1604    315
# Name: ML Odds, dtype: int64
# 304    145
# Name: ML Odds, dtype: int64
# 1635    125
# Name: ML Odds, dtype: int64
# 347   -140
# Name: ML Odds, dtype: int64
# 374    800
# Name: ML Odds, dtype: int64
# 2050   -150
# Name: ML Odds, dtype: int64
# 380    175
# Name: ML Odds, dtype: int64
# 431    175
# Name: ML Odds, dtype: int64
# 444    260
# Name: ML Odds, dtype: int64
# 471    485
# Name: ML Odds, dtype: int64
# 478    500
# Name: ML Odds, dtype: int64
# 496    700
# Name: ML Odds, dtype: int64
# 515    180
# Name: ML Odds, dtype: int64
# 530    315
# Name: ML Odds, dtype: int64
# 571    175
# Name: ML Odds, dtype: int64
# 583    105
# Name: ML Odds, dtype: int64
# 600    650
# Name: ML Odds, dtype: int64
# 630    500
# Name: ML Odds, dtype: int64
# 653   -160
# Name: ML Odds, dtype: int64
# 663    240
# Name: ML Odds, dtype: int64
# 677   -107
# Name: ML Odds, dtype: int64
# 683    210
# Name: ML Odds, dtype: int64
# 704    290
# Name: ML Odds, dtype: int64
# 730    475
# Name: ML Odds, dtype: int64
# 748    290
# Name: ML Odds, dtype: int64
# 772    1100
# Name: ML Odds, dtype: int64
# 801    315
# Name: ML Odds, dtype: int64
# 811    320
# Name: ML Odds, dtype: int64
# 2397    375
# Name: ML Odds, dtype: int64
# 1762    135
# Name: ML Odds, dtype: int64
# 1786    315
# Name: ML Odds, dtype: int64
# 904    145
# Name: ML Odds, dtype: int64
# 926    1150
# Name: ML Odds, dtype: int64
# 2235   -135
# Name: ML Odds, dtype: int64
# 962    1000
# Name: ML Odds, dtype: int64
# 991    145
# Name: ML Odds, dtype: int64
# 1011    115
# Name: ML Odds, dtype: int64
# 1844    425
# Name: ML Odds, dtype: int64
# 1049    180
# Name: ML Odds, dtype: int64
# 1065    140
# Name: ML Odds, dtype: int64
# 1068    315
# Name: ML Odds, dtype: int64
# 1096    355
# Name: ML Odds, dtype: int64
# 1120    700
# Name: ML Odds, dtype: int64
# 1863    245
# Name: ML Odds, dtype: int64
# 1157    115
# Name: ML Odds, dtype: int64
# 1167   -330
# Name: ML Odds, dtype: int64
# 1183    350
# Name: ML Odds, dtype: int64
# 1202    2750
# Name: ML Odds, dtype: int64
# 2311    145
# Name: ML Odds, dtype: int64
# 1271   -200
# Name: ML Odds, dtype: int64
# 2352    475
# Name: ML Odds, dtype: int64
# 1288    110
# Name: ML Odds, dtype: int64
# 1304    425
# Name: ML Odds, dtype: int64
# 1326    245
# Name: ML Odds, dtype: int64
# 1944    155
# Name: ML Odds, dtype: int64
# 1979    270
# Name: ML Odds, dtype: int64
# 1999    450
# Name: ML Odds, dtype: int64
# 1361    600
# Name: ML Odds, dtype: int64
# 2276    1750
# Name: ML Odds, dtype: int64
# 1382    550
# Name: ML Odds, dtype: int64
# 1411   -220
# Name: ML Odds, dtype: int64
# 1429    170
# Name: ML Odds, dtype: int64
# 1448    165
# Name: ML Odds, dtype: int64
# 1481   -160
# Name: ML Odds, dtype: int64
# 1499    140
# Name: ML Odds, dtype: int64
# 6    525
# Name: ML Odds, dtype: int64
# 1516    385
# Name: ML Odds, dtype: int64
# 57    170
# Name: ML Odds, dtype: int64
# 81    120
# Name: ML Odds, dtype: int64
# 2150    155
# Name: ML Odds, dtype: int64
# 86    115
# Name: ML Odds, dtype: int64
# 1536    255
# Name: ML Odds, dtype: int64
# 100    145
# Name: ML Odds, dtype: int64
# 116    500
# Name: ML Odds, dtype: int64
# 2375   -175
# Name: ML Odds, dtype: int64
# 194    600
# Name: ML Odds, dtype: int64
# 215    120
# Name: ML Odds, dtype: int64
# 229    105
# Name: ML Odds, dtype: int64
# 248    160
# Name: ML Odds, dtype: int64
# 267    190
# Name: ML Odds, dtype: int64
# 2041    130
# Name: ML Odds, dtype: int64
# 1619    165
# Name: ML Odds, dtype: int64
# 315   -200
# Name: ML Odds, dtype: int64
# 328    185
# Name: ML Odds, dtype: int64
# 343    360
# Name: ML Odds, dtype: int64
# 371   -125
# Name: ML Odds, dtype: int64
# 2044    600
# Name: ML Odds, dtype: int64
# 2064    300
# Name: ML Odds, dtype: int64
# 396    160
# Name: ML Odds, dtype: int64
# 412    130
# Name: ML Odds, dtype: int64
# 2196    160
# Name: ML Odds, dtype: int64
# 2210    375
# Name: ML Odds, dtype: int64
# 1671   -475
# Name: ML Odds, dtype: int64
# 2080    650
# Name: ML Odds, dtype: int64
# 529   -305
# Name: ML Odds, dtype: int64
# 567    155
# Name: ML Odds, dtype: int64
# 1678   -130
# Name: ML Odds, dtype: int64
# 599   -130
# Name: ML Odds, dtype: int64
# 618    475
# Name: ML Odds, dtype: int64
# 640    600
# Name: ML Odds, dtype: int64
# 1704    600
# Name: ML Odds, dtype: int64
# 673    290
# Name: ML Odds, dtype: int64
# 705   -350
# Name: ML Odds, dtype: int64
# 2414    550
# Name: ML Odds, dtype: int64
# 734    500
# Name: ML Odds, dtype: int64
# 1738    260
# Name: ML Odds, dtype: int64
# 2105   -170
# Name: ML Odds, dtype: int64
# 1753   -380
# Name: ML Odds, dtype: int64
# 833    255
# Name: ML Odds, dtype: int64
# 851    450
# Name: ML Odds, dtype: int64
# 1770    350
# Name: ML Odds, dtype: int64
# 1793    220
# Name: ML Odds, dtype: int64
# 920    175
# Name: ML Odds, dtype: int64
# 1809   -225
# Name: ML Odds, dtype: int64
# 2118    200
# Name: ML Odds, dtype: int64
# 960    145
# Name: ML Odds, dtype: int64
# 987    180
# Name: ML Odds, dtype: int64
# 1819    180
# Name: ML Odds, dtype: int64
# 1845   -550
# Name: ML Odds, dtype: int64
# 1044   -165
# Name: ML Odds, dtype: int64
# 2137   -165
# Name: ML Odds, dtype: int64
# 1076    270
# Name: ML Odds, dtype: int64
# 1086    100
# Name: ML Odds, dtype: int64
# 1114   -250
# Name: ML Odds, dtype: int64
# 1854    115
# Name: ML Odds, dtype: int64
# 1155   -1600
# Name: ML Odds, dtype: int64
# 1163   -118
# Name: ML Odds, dtype: int64
# 1927   -330
# Name: ML Odds, dtype: int64
# 1199   -200
# Name: ML Odds, dtype: int64
# 1225   -165
# Name: ML Odds, dtype: int64
# 2310   -165
# Name: ML Odds, dtype: int64
# 2408    355
# Name: ML Odds, dtype: int64
# 1939   -1100
# Name: ML Odds, dtype: int64
# 1291   -185
# Name: ML Odds, dtype: int64
# 1320    115
# Name: ML Odds, dtype: int64
# 2263    160
# Name: ML Odds, dtype: int64
# 1950   -200
# Name: ML Odds, dtype: int64
# 1975   -175
# Name: ML Odds, dtype: int64
# 2016    105
# Name: ML Odds, dtype: int64
# 1358    130
# Name: ML Odds, dtype: int64
# 1381   -700
# Name: ML Odds, dtype: int64
# 1409    125
# Name: ML Odds, dtype: int64
# 2320    260
# Name: ML Odds, dtype: int64
# 1447   -750
# Name: ML Odds, dtype: int64
# 1462    550
# Name: ML Odds, dtype: int64
# 1503    150
# Name: ML Odds, dtype: int64
# 17    180
# Name: ML Odds, dtype: int64
# 2140    460
# Name: ML Odds, dtype: int64
# 1514    265
# Name: ML Odds, dtype: int64
# 59   -150
# Name: ML Odds, dtype: int64
# 78    160
# Name: ML Odds, dtype: int64
# 2152   -125
# Name: ML Odds, dtype: int64
# 2170    230
# Name: ML Odds, dtype: int64
# 2336    230
# Name: ML Odds, dtype: int64
# 127    120
# Name: ML Odds, dtype: int64
# 2377   -150
# Name: ML Odds, dtype: int64
# 2419   -112
# Name: ML Odds, dtype: int64
# 206   -400
# Name: ML Odds, dtype: int64
# 2032    135
# Name: ML Odds, dtype: int64
# 246    190
# Name: ML Odds, dtype: int64
# 1578    350
# Name: ML Odds, dtype: int64
# 1593    120
# Name: ML Odds, dtype: int64
# 285   -103
# Name: ML Odds, dtype: int64
# 317   -165
# Name: ML Odds, dtype: int64
# 2287   -300
# Name: ML Odds, dtype: int64
# 329   -225
# Name: ML Odds, dtype: int64
# 346    130
# Name: ML Odds, dtype: int64
# 351    105
# Name: ML Odds, dtype: int64
# 2191   -250
# Name: ML Odds, dtype: int64
# 2069    290
# Name: ML Odds, dtype: int64
# 2383   -240
# Name: ML Odds, dtype: int64
# 445   -320
# Name: ML Odds, dtype: int64
# 2218    650
# Name: ML Odds, dtype: int64
# 503    105
# Name: ML Odds, dtype: int64
# 1673   -210
# Name: ML Odds, dtype: int64
# 2076    105
# Name: ML Odds, dtype: int64
# 536   -130
# Name: ML Odds, dtype: int64
# 2292   -117
# Name: ML Odds, dtype: int64
# 576    130
# Name: ML Odds, dtype: int64
# 627    290
# Name: ML Odds, dtype: int64
# 649   -165
# Name: ML Odds, dtype: int64
# 661   -165
# Name: ML Odds, dtype: int64
# 675    175
# Name: ML Odds, dtype: int64
# 707   -170
# Name: ML Odds, dtype: int64
# 2097    240
# Name: ML Odds, dtype: int64
# 732    525
# Name: ML Odds, dtype: int64
# 755   -235
# Name: ML Odds, dtype: int64
# 778    1250
# Name: ML Odds, dtype: int64
# 818    260
# Name: ML Odds, dtype: int64
# 844    310
# Name: ML Odds, dtype: int64
# 858    200
# Name: ML Odds, dtype: int64
# 1773    425
# Name: ML Odds, dtype: int64
# 897    110
# Name: ML Odds, dtype: int64
# 1808    185
# Name: ML Odds, dtype: int64
# 941    230
# Name: ML Odds, dtype: int64
# 2232    435
# Name: ML Odds, dtype: int64
# 952    380
# Name: ML Odds, dtype: int64
# 989   -165
# Name: ML Odds, dtype: int64
# 2244    380
# Name: ML Odds, dtype: int64
# 1847    245
# Name: ML Odds, dtype: int64
# 1047    295
# Name: ML Odds, dtype: int64
# 1063    320
# Name: ML Odds, dtype: int64
# 1072   -145
# Name: ML Odds, dtype: int64
# 1102    438
# Name: ML Odds, dtype: int64
# 1112   -120
# Name: ML Odds, dtype: int64
# 1132    160
# Name: ML Odds, dtype: int64
# 1868    550
# Name: ML Odds, dtype: int64
# 1882    300
# Name: ML Odds, dtype: int64
# 1902   -175
# Name: ML Odds, dtype: int64
# 1920    325
# Name: ML Odds, dtype: int64
# 1201    175
# Name: ML Odds, dtype: int64
# 1221    305
# Name: ML Odds, dtype: int64
# 1245    140
# Name: ML Odds, dtype: int64
# 1261    145
# Name: ML Odds, dtype: int64
# 2359   -380
# Name: ML Odds, dtype: int64
# 1296    315
# Name: ML Odds, dtype: int64
# 1312    245
# Name: ML Odds, dtype: int64
# 1952    325
# Name: ML Odds, dtype: int64
# 1972    600
# Name: ML Odds, dtype: int64
# 1997    180
# Name: ML Odds, dtype: int64
# 1359   -140
# Name: ML Odds, dtype: int64
# 2275   -600
# Name: ML Odds, dtype: int64
# 1380    500
# Name: ML Odds, dtype: int64
# 1402    1000
# Name: ML Odds, dtype: int64
# 1418    450
# Name: ML Odds, dtype: int64
# 1449   -175
# Name: ML Odds, dtype: int64
# 1480    150
# Name: ML Odds, dtype: int64
# 1493    155
# Name: ML Odds, dtype: int64
# 2    650
# Name: ML Odds, dtype: int64
# 2145   -175
# Name: ML Odds, dtype: int64
# 27   -125
# Name: ML Odds, dtype: int64
# 46    160
# Name: ML Odds, dtype: int64
# 70    180
# Name: ML Odds, dtype: int64
# 1522    230
# Name: ML Odds, dtype: int64
# 89    105
# Name: ML Odds, dtype: int64
# 1543   -245
# Name: ML Odds, dtype: int64
# 101   -165
# Name: ML Odds, dtype: int64
# 2363   -120
# Name: ML Odds, dtype: int64
# 2372    145
# Name: ML Odds, dtype: int64
# 168    105
# Name: ML Odds, dtype: int64
# 205   -1000
# Name: ML Odds, dtype: int64
# 224    325
# Name: ML Odds, dtype: int64
# 242    725
# Name: ML Odds, dtype: int64
# 1576    260
# Name: ML Odds, dtype: int64
# 1595    130
# Name: ML Odds, dtype: int64
# 275    100
# Name: ML Odds, dtype: int64
# 289    315
# Name: ML Odds, dtype: int64
# 298    160
# Name: ML Odds, dtype: int64
# 1633    260
# Name: ML Odds, dtype: int64
# 338    250
# Name: ML Odds, dtype: int64
# 1650    500
# Name: ML Odds, dtype: int64
# 356    250
# Name: ML Odds, dtype: int64
# 2055    240
# Name: ML Odds, dtype: int64
# 2063    270
# Name: ML Odds, dtype: int64
# 2378    525
# Name: ML Odds, dtype: int64
# 2193    260
# Name: ML Odds, dtype: int64
# 432    800
# Name: ML Odds, dtype: int64
# 473    190
# Name: ML Odds, dtype: int64
# 1672    190
# Name: ML Odds, dtype: int64
# 512    700
# Name: ML Odds, dtype: int64
# 540    775
# Name: ML Odds, dtype: int64
# 555    110
# Name: ML Odds, dtype: int64
# 579    210
# Name: ML Odds, dtype: int64
# 596    1050
# Name: ML Odds, dtype: int64
# 612    1300
# Name: ML Odds, dtype: int64
# 2223    600
# Name: ML Odds, dtype: int64
# 1693    260
# Name: ML Odds, dtype: int64
# 678    210
# Name: ML Odds, dtype: int64
# 723    255
# Name: ML Odds, dtype: int64
# 738    105
# Name: ML Odds, dtype: int64
# 761    125
# Name: ML Odds, dtype: int64
# 2098    375
# Name: ML Odds, dtype: int64
# 829    380
# Name: ML Odds, dtype: int64
# 2392    310
# Name: ML Odds, dtype: int64
# 1763   -155
# Name: ML Odds, dtype: int64
# 1767   -120
# Name: ML Odds, dtype: int64
# 900    245
# Name: ML Odds, dtype: int64
# 1801    775
# Name: ML Odds, dtype: int64
# 2114    170
# Name: ML Odds, dtype: int64
# 942    175
# Name: ML Odds, dtype: int64
# 975    185
# Name: ML Odds, dtype: int64
# 995    1500
# Name: ML Odds, dtype: int64
# 1828    700
# Name: ML Odds, dtype: int64
# 1028    1000
# Name: ML Odds, dtype: int64
# 2129    700
# Name: ML Odds, dtype: int64
# 1073    125
# Name: ML Odds, dtype: int64
# 1082    1000
# Name: ML Odds, dtype: int64
# 1137    350
# Name: ML Odds, dtype: int64
# 1874    400
# Name: ML Odds, dtype: int64
# 1154    1050
# Name: ML Odds, dtype: int64
# 1166    270
# Name: ML Odds, dtype: int64
# 1928    2750
# Name: ML Odds, dtype: int64
# 1180    568
# Name: ML Odds, dtype: int64
# 2247    800
# Name: ML Odds, dtype: int64
# 2305   -118
# Name: ML Odds, dtype: int64
# 1226    180
# Name: ML Odds, dtype: int64
# 1258    925
# Name: ML Odds, dtype: int64
# 1933    1000
# Name: ML Odds, dtype: int64
# 1275    1250
# Name: ML Odds, dtype: int64
# 1311    425
# Name: ML Odds, dtype: int64
# 2258    1750
# Name: ML Odds, dtype: int64
# 1965    425
# Name: ML Odds, dtype: int64
# 1980    1250
# Name: ML Odds, dtype: int64
# 1357    100
# Name: ML Odds, dtype: int64
# 1371    700
# Name: ML Odds, dtype: int64
# 1393    350
# Name: ML Odds, dtype: int64
# 2312    550
# Name: ML Odds, dtype: int64
# 1436    1100
# Name: ML Odds, dtype: int64
# 1473    320
# Name: ML Odds, dtype: int64
# 2327   -600
# Name: ML Odds, dtype: int64
# 1510    165
# Name: ML Odds, dtype: int64
# 33   -150
# Name: ML Odds, dtype: int64
# 1532    255
# Name: ML Odds, dtype: int64
# 84    205
# Name: ML Odds, dtype: int64
# 1545   -800
# Name: ML Odds, dtype: int64
# 105   -310
# Name: ML Odds, dtype: int64
# 148    135
# Name: ML Odds, dtype: int64
# 2376    130
# Name: ML Odds, dtype: int64
# 192   -140
# Name: ML Odds, dtype: int64
# 214   -140
# Name: ML Odds, dtype: int64
# 2033   -155
# Name: ML Odds, dtype: int64
# 1566    120
# Name: ML Odds, dtype: int64
# 256    170
# Name: ML Odds, dtype: int64
# 277    120
# Name: ML Odds, dtype: int64
# 292    350
# Name: ML Odds, dtype: int64
# 2288    425
# Name: ML Odds, dtype: int64
# 1634   -145
# Name: ML Odds, dtype: int64
# 339   -300
# Name: ML Odds, dtype: int64
# 1648    240
# Name: ML Odds, dtype: int64
# 369   -135
# Name: ML Odds, dtype: int64
# 2049    200
# Name: ML Odds, dtype: int64
# 2065   -360
# Name: ML Odds, dtype: int64
# 2380    175
# Name: ML Odds, dtype: int64
# 2195   -185
# Name: ML Odds, dtype: int64
# 448    305
# Name: ML Odds, dtype: int64
# 454   -125
# Name: ML Odds, dtype: int64
# 493   -170
# Name: ML Odds, dtype: int64
# 1664    425
# Name: ML Odds, dtype: int64
# 525   -130
# Name: ML Odds, dtype: int64
# 544    175
# Name: ML Odds, dtype: int64
# 559    110
# Name: ML Odds, dtype: int64
# 595   -150
# Name: ML Odds, dtype: int64
# 608   -175
# Name: ML Odds, dtype: int64
# 643   -130
# Name: ML Odds, dtype: int64
# 1712   -210
# Name: ML Odds, dtype: int64
# 1722    155
# Name: ML Odds, dtype: int64
# 684   -300
# Name: ML Odds, dtype: int64
# 2410    305
# Name: ML Odds, dtype: int64
# 722   -310
# Name: ML Odds, dtype: int64
# 749   -350
# Name: ML Odds, dtype: int64
# 770   -310
# Name: ML Odds, dtype: int64
# 787    125
# Name: ML Odds, dtype: int64
# 1751   -1400
# Name: ML Odds, dtype: int64
# 825   -250
# Name: ML Odds, dtype: int64
# 847    215
# Name: ML Odds, dtype: int64
# 885    170
# Name: ML Odds, dtype: int64
# 1789   -150
# Name: ML Odds, dtype: int64
# 916    170
# Name: ML Odds, dtype: int64
# 1797    105
# Name: ML Odds, dtype: int64
# 2119   -220
# Name: ML Odds, dtype: int64
# 957   -165
# Name: ML Odds, dtype: int64
# 968   -220
# Name: ML Odds, dtype: int64
# 2238    105
# Name: ML Odds, dtype: int64
# 1813    260
# Name: ML Odds, dtype: int64
# 1835    125
# Name: ML Odds, dtype: int64
# 1041    105
# Name: ML Odds, dtype: int64
# 1066   -220
# Name: ML Odds, dtype: int64
# 2302    323
# Name: ML Odds, dtype: int64
# 1101   -160
# Name: ML Odds, dtype: int64
# 1125   -290
# Name: ML Odds, dtype: int64
# 1131    100
# Name: ML Odds, dtype: int64
# 1872    115
# Name: ML Odds, dtype: int64
# 1148    135
# Name: ML Odds, dtype: int64
# 1175   -310
# Name: ML Odds, dtype: int64
# 2251   -300
# Name: ML Odds, dtype: int64
# 2308   -120
# Name: ML Odds, dtype: int64
# 1246    1025
# Name: ML Odds, dtype: int64
# 1256    425
# Name: ML Odds, dtype: int64
# 1287    103
# Name: ML Odds, dtype: int64
# 1313   -290
# Name: ML Odds, dtype: int64
# 1329   -1100
# Name: ML Odds, dtype: int64
# 1978   -330
# Name: ML Odds, dtype: int64
# 1996   -220
# Name: ML Odds, dtype: int64
# 2018    180
# Name: ML Odds, dtype: int64
# 2273    145
# Name: ML Odds, dtype: int64
# 1376    175
# Name: ML Odds, dtype: int64
# 1401   -500
# Name: ML Odds, dtype: int64
# 1424    165
# Name: ML Odds, dtype: int64
# 1442   -1100
# Name: ML Odds, dtype: int64
# 1465    175
# Name: ML Odds, dtype: int64
# 1496    235
# Name: ML Odds, dtype: int64
# 4    145
# Name: ML Odds, dtype: int64
# 47   -185
# Name: ML Odds, dtype: int64
# 73   -185
# Name: ML Odds, dtype: int64
# 2151   -175
# Name: ML Odds, dtype: int64
# 90    428
# Name: ML Odds, dtype: int64
# 1534    205
# Name: ML Odds, dtype: int64
# 108    145
# Name: ML Odds, dtype: int64
# 122    500
# Name: ML Odds, dtype: int64
# 139   -185
# Name: ML Odds, dtype: int64
# 163    120
# Name: ML Odds, dtype: int64
# 178    240
# Name: ML Odds, dtype: int64
# 2030    135
# Name: ML Odds, dtype: int64
# 239    325
# Name: ML Odds, dtype: int64
# 1571   -160
# Name: ML Odds, dtype: int64
# 1591    325
# Name: ML Odds, dtype: int64
# 273   -120
# Name: ML Odds, dtype: int64
# 1606    160
# Name: ML Odds, dtype: int64
# 2279   -500
# Name: ML Odds, dtype: int64
# 1627    400
# Name: ML Odds, dtype: int64
# 335    290
# Name: ML Odds, dtype: int64
# 372    425
# Name: ML Odds, dtype: int64
# 2190    210
# Name: ML Odds, dtype: int64
# 390    700
# Name: ML Odds, dtype: int64
# 399    245
# Name: ML Odds, dtype: int64
# 419    290
# Name: ML Odds, dtype: int64
# 436    125
# Name: ML Odds, dtype: int64
# 487    130
# Name: ML Odds, dtype: int64
# 504    380
# Name: ML Odds, dtype: int64
# 516   -120
# Name: ML Odds, dtype: int64
# 554   -130
# Name: ML Odds, dtype: int64
# 577   -150
# Name: ML Odds, dtype: int64
# 2388    320
# Name: ML Odds, dtype: int64
# 620    385
# Name: ML Odds, dtype: int64
# 637    130
# Name: ML Odds, dtype: int64
# 1701   -210
# Name: ML Odds, dtype: int64
# 1714    210
# Name: ML Odds, dtype: int64
# 1723   -165
# Name: ML Odds, dtype: int64
# 688   -125
# Name: ML Odds, dtype: int64
# 2085   -1200
# Name: ML Odds, dtype: int64
# 714    290
# Name: ML Odds, dtype: int64
# 741   -440
# Name: ML Odds, dtype: int64
# 2100   -125
# Name: ML Odds, dtype: int64
# 792    240
# Name: ML Odds, dtype: int64
# 805    260
# ...
# Name: ML Odds, dtype: int64
# 2330    130
# Name: ML Odds, dtype: int64
# 1533   -310
# Name: ML Odds, dtype: int64
# 92    120
# Name: ML Odds, dtype: int64
# 2174    210
# Name: ML Odds, dtype: int64
# 112   -340
# Name: ML Odds, dtype: int64
# 126   -140
# Name: ML Odds, dtype: int64
# 147   -3000
# Name: ML Odds, dtype: int64
# 154    120
# Name: ML Odds, dtype: int64
# 186   -400
# Name: ML Odds, dtype: int64
# 211   -620
# Name: ML Odds, dtype: int64
# 251   -1250
# Name: ML Odds, dtype: int64
# 1579   -395
# Name: ML Odds, dtype: int64
# 1586   -350
# Name: ML Odds, dtype: int64
# 2038   -1300
# Name: ML Odds, dtype: int64
# 1608   -440
# Name: ML Odds, dtype: int64
# 306    105
# Name: ML Odds, dtype: int64
# 2285   -1000
# Name: ML Odds, dtype: int64
# 342   -450
# Name: ML Odds, dtype: int64
# 1651   -700
# Name: ML Odds, dtype: int64
# 375   -1250
# Name: ML Odds, dtype: int64
# 2056   -165
# Name: ML Odds, dtype: int64
# 388    185
# Name: ML Odds, dtype: int64
# 405   -145
# Name: ML Odds, dtype: int64
# 427   -185
# Name: ML Odds, dtype: int64
# 2200    535
# Name: ML Odds, dtype: int64
# 2217   -120
# Name: ML Odds, dtype: int64
# 475   -220
# Name: ML Odds, dtype: int64
# 492    150
# Name: ML Odds, dtype: int64
# 507   -118
# Name: ML Odds, dtype: int64
# 520    110
# Name: ML Odds, dtype: int64
# 545   -190
# Name: ML Odds, dtype: int64
# 1685   -215
# Name: ML Odds, dtype: int64
# 2389   -390
# Name: ML Odds, dtype: int64
# 647   -210
# Name: ML Odds, dtype: int64
# 1706   -600
# Name: ML Odds, dtype: int64
# 668    105
# Name: ML Odds, dtype: int64
# 1720   -185
# Name: ML Odds, dtype: int64
# 701   -185
# Name: ML Odds, dtype: int64
# 2415   -800
# Name: ML Odds, dtype: int64
# 2434   -320
# Name: ML Odds, dtype: int64
# 1740   -200
# Name: ML Odds, dtype: int64
# 773   -1700
# Name: ML Odds, dtype: int64
# 795   -900
# Name: ML Odds, dtype: int64
# 831   -1400
# Name: ML Odds, dtype: int64
# 871   -220
# Name: ML Odds, dtype: int64
# 1791   -1250
# Name: ML Odds, dtype: int64
# 923   -600
# Name: ML Odds, dtype: int64
# 936   -120
# Name: ML Odds, dtype: int64
# 2110   -190
# Name: ML Odds, dtype: int64
# 946   -235
# Name: ML Odds, dtype: int64
# 2344   -145
# Name: ML Odds, dtype: int64
# 992    250
# Name: ML Odds, dtype: int64
# 1818   -220
# Name: ML Odds, dtype: int64
# 1848    135
# Name: ML Odds, dtype: int64
# 1046   -325
# Name: ML Odds, dtype: int64
# 2138    103
# Name: ML Odds, dtype: int64
# 1103   -575
# Name: ML Odds, dtype: int64
# 1127   -1100
# Name: ML Odds, dtype: int64
# 1851   -550
# Name: ML Odds, dtype: int64
# 1151   -330
# Name: ML Odds, dtype: int64
# 1165    107
# Name: ML Odds, dtype: int64
# 1179   -1500
# Name: ML Odds, dtype: int64
# 2246   -1250
# Name: ML Odds, dtype: int64
# 1212   -185
# Name: ML Odds, dtype: int64
# 1243   -500
# Name: ML Odds, dtype: int64
# 1252    115
# Name: ML Odds, dtype: int64
# 2356   -155
# Name: ML Odds, dtype: int64
# 1295   -330
# Name: ML Odds, dtype: int64
# 1319   -440
# Name: ML Odds, dtype: int64
# 1339   -380
# Name: ML Odds, dtype: int64
# 2424   -250
# Name: ML Odds, dtype: int64
# 1960   -450
# Name: ML Odds, dtype: int64
# 1995   -1250
# Name: ML Odds, dtype: int64
# 1355   -215
# Name: ML Odds, dtype: int64
# 2270   -220
# Name: ML Odds, dtype: int64
# 1379   -220
# Name: ML Odds, dtype: int64
# 1404   -145
# Name: ML Odds, dtype: int64
# 1427   -3000
# Name: ML Odds, dtype: int64
# 1464   -210
# Name: ML Odds, dtype: int64
# 2328   -280
# Name: ML Odds, dtype: int64
# 1498   -160
# Name: ML Odds, dtype: int64
# 1506   -545
# Name: ML Odds, dtype: int64
# 28    110
# Name: ML Odds, dtype: int64
# 2331   -150
# Name: ML Odds, dtype: int64
# 1529   -120
# Name: ML Odds, dtype: int64
# 1550   -270
# Name: ML Odds, dtype: int64
# 107   -5000
# Name: ML Odds, dtype: int64
# 2366   -175
# Name: ML Odds, dtype: int64
# 144    145
# Name: ML Odds, dtype: int64
# 173   -900
# Name: ML Odds, dtype: int64
# 209    130
# Name: ML Odds, dtype: int64
# 225   -400
# Name: ML Odds, dtype: int64
# 247   -210
# Name: ML Odds, dtype: int64
# 1575    145
# Name: ML Odds, dtype: int64
# 264    120
# Name: ML Odds, dtype: int64
# 1615    190
# Name: ML Odds, dtype: int64
# 308   -280
# Name: ML Odds, dtype: int64
# 2281   -105
# Name: ML Odds, dtype: int64
# 1654    525
# Name: ML Odds, dtype: int64
# 350   -115
# Name: ML Odds, dtype: int64
# 2189   -280
# Name: ML Odds, dtype: int64
# 408   -105
# Name: ML Odds, dtype: int64
# 2381   -210
# Name: ML Odds, dtype: int64
# 2199   -200
# Name: ML Odds, dtype: int64
# 2209   -165
# Name: ML Odds, dtype: int64
# 490    120
# Name: ML Odds, dtype: int64
# 506   -102
# Name: ML Odds, dtype: int64
# 2079   -175
# Name: ML Odds, dtype: int64
# 547   -860
# Name: ML Odds, dtype: int64
# 558   -130
# Name: ML Odds, dtype: int64
# 1681   -350
# Name: ML Odds, dtype: int64
# 592    135
# Name: ML Odds, dtype: int64
# 606   -310
# Name: ML Odds, dtype: int64
# 2222   -900
# Name: ML Odds, dtype: int64
# 1705   -900
# Name: ML Odds, dtype: int64
# 1710   -280
# Name: ML Odds, dtype: int64
# 1718   -400
# Name: ML Odds, dtype: int64
# 681   -125
# Name: ML Odds, dtype: int64
# 2091   -140
# Name: ML Odds, dtype: int64
# 725   -550
# Name: ML Odds, dtype: int64
# 756    315
# Name: ML Odds, dtype: int64
# 774    115
# Name: ML Odds, dtype: int64
# 800   -380
# Name: ML Odds, dtype: int64
# 827   -175
# Name: ML Odds, dtype: int64
# 842   -250
# Name: ML Odds, dtype: int64
# 860   -200
# Name: ML Odds, dtype: int64
# 1783   -145
# Name: ML Odds, dtype: int64
# 915   -235
# Name: ML Odds, dtype: int64
# 939   -185
# Name: ML Odds, dtype: int64
# 2230    115
# Name: ML Odds, dtype: int64
# 964    145
# Name: ML Odds, dtype: int64
# 984    110
# Name: ML Odds, dtype: int64
# 2243   -155
# Name: ML Odds, dtype: int64
# 1817   -500
# Name: ML Odds, dtype: int64
# 1839   -165
# Name: ML Odds, dtype: int64
# 1039   -250
# Name: ML Odds, dtype: int64
# 1055   -105
# Name: ML Odds, dtype: int64
# 1074    380
# Name: ML Odds, dtype: int64
# 1095   -170
# Name: ML Odds, dtype: int64
# 1123   -330
# Name: ML Odds, dtype: int64
# 1144   -210
# Name: ML Odds, dtype: int64
# 1896    135
# Name: ML Odds, dtype: int64
# 1162   -102
# Name: ML Odds, dtype: int64
# 1170    145
# Name: ML Odds, dtype: int64
# 2253   -900
# Name: ML Odds, dtype: int64
# 2307   -380
# Name: ML Odds, dtype: int64
# 2407   -440
# Name: ML Odds, dtype: int64
# 1930    100
# Name: ML Odds, dtype: int64
# 1286   -123
# Name: ML Odds, dtype: int64
# 1315   -1250
# Name: ML Odds, dtype: int64
# 1324   -145
# Name: ML Odds, dtype: int64
# 1946    105
# Name: ML Odds, dtype: int64
# 1973   -900
# Name: ML Odds, dtype: int64
# 1344    115
# Name: ML Odds, dtype: int64
# 1348    115
# Name: ML Odds, dtype: int64
# 1378    180
# Name: ML Odds, dtype: int64
# 1405    125
# Name: ML Odds, dtype: int64
# 1425   -190
# Name: ML Odds, dtype: int64
# 1430   -650
# Name: ML Odds, dtype: int64
# 1463   -800
# Name: ML Odds, dtype: int64
# 1504    360
# Name: ML Odds, dtype: int64
# 8    650
# Name: ML Odds, dtype: int64
# 1508    248
# Name: ML Odds, dtype: int64
# 24    475
# Name: ML Odds, dtype: int64
# 77    255
# Name: ML Odds, dtype: int64
# 2153    105
# Name: ML Odds, dtype: int64
# 2168    130
# Name: ML Odds, dtype: int64
# 1538    180
# Name: ML Odds, dtype: int64
# 109   -165
# Name: ML Odds, dtype: int64
# 2367    155
# Name: ML Odds, dtype: int64
# 2374    155
# Name: ML Odds, dtype: int64
# 170    260
# Name: ML Odds, dtype: int64
# 189   -120
# Name: ML Odds, dtype: int64
# 1559    290
# Name: ML Odds, dtype: int64
# 249   -185
# Name: ML Odds, dtype: int64
# 1577   -320
# Name: ML Odds, dtype: int64
# 276   -140
# Name: ML Odds, dtype: int64
# 296   -1100
# Name: ML Odds, dtype: int64
# 1626   -500
# Name: ML Odds, dtype: int64
# 341   -570
# Name: ML Odds, dtype: int64
# 349   -140
# Name: ML Odds, dtype: int64
# 366   -485
# Name: ML Odds, dtype: int64
# 2053   -280
# Name: ML Odds, dtype: int64
# 2068   -350
# Name: ML Odds, dtype: int64
# 2384    125
# Name: ML Odds, dtype: int64
# 430   -210
# Name: ML Odds, dtype: int64
# 449   -335
# Name: ML Odds, dtype: int64
# 465   -300
# Name: ML Odds, dtype: int64
# 474    180
# Name: ML Odds, dtype: int64
# 495   -260
# Name: ML Odds, dtype: int64
# 508    135
# Name: ML Odds, dtype: int64
# 549   -310
# Name: ML Odds, dtype: int64
# 561   -340
# Name: ML Odds, dtype: int64
# 604    130
# Name: ML Odds, dtype: int64
# 626   -350
# Name: ML Odds, dtype: int64
# 641   -900
# Name: ML Odds, dtype: int64
# 680    105
# Name: ML Odds, dtype: int64
# 697    120
# Name: ML Odds, dtype: int64
# 2412   -485
# Name: ML Odds, dtype: int64
# 2432   -280
# Name: ML Odds, dtype: int64
# 750    110
# Name: ML Odds, dtype: int64
# 764    155
# Name: ML Odds, dtype: int64
# 782    145
# Name: ML Odds, dtype: int64
# 1747   -2000
# Name: ML Odds, dtype: int64
# 828   -475
# Name: ML Odds, dtype: int64
# 866    255
# Name: ML Odds, dtype: int64
# 887   -1400
# Name: ML Odds, dtype: int64
# 1788    130
# Name: ML Odds, dtype: int64
# 917   -200
# Name: ML Odds, dtype: int64
# 925   -165
# Name: ML Odds, dtype: int64
# 2124   -270
# Name: ML Odds, dtype: int64
# 951   -250
# Name: ML Odds, dtype: int64
# 2343   -220
# Name: ML Odds, dtype: int64
# 2236   -230
# Name: ML Odds, dtype: int64
# 1005   -600
# Name: ML Odds, dtype: int64
# 1017   -290
# Name: ML Odds, dtype: int64
# 1022   -215
# Name: ML Odds, dtype: int64
# 1050    170
# Name: ML Odds, dtype: int64
# 1064   -160
# Name: ML Odds, dtype: int64
# 1099   -1750
# Name: ML Odds, dtype: int64
# 2346   -185
# Name: ML Odds, dtype: int64
# 1861   -290
# Name: ML Odds, dtype: int64
# 1891   -290
# Name: ML Odds, dtype: int64
# 1909   -800
# Name: ML Odds, dtype: int64
# 1169   -360
# Name: ML Odds, dtype: int64
# 1196    135
# Name: ML Odds, dtype: int64
# 1219   -290
# Name: ML Odds, dtype: int64
# 1237    115
# Name: ML Odds, dtype: int64
# 1251   -165
# Name: ML Odds, dtype: int64
# 2353   -650
# Name: ML Odds, dtype: int64
# 1294    270
# Name: ML Odds, dtype: int64
# 2262   -185
# Name: ML Odds, dtype: int64
# 1340   -118
# Name: ML Odds, dtype: int64
# 1971   -155
# Name: ML Odds, dtype: int64
# 1988    170
# Name: ML Odds, dtype: int64
# 1349   -135
# Name: ML Odds, dtype: int64
# 2271    180
# Name: ML Odds, dtype: int64
# 1403   -1500
# Name: ML Odds, dtype: int64
# 1422    145
# Name: ML Odds, dtype: int64
# 1445   -365
# Name: ML Odds, dtype: int64
# 1456   -1500
# Name: ML Odds, dtype: int64
# 1489   -190
# Name: ML Odds, dtype: int64
# 2142    130
# Name: ML Odds, dtype: int64
# 25   -650
# Name: ML Odds, dtype: int64
# 42   -103
# Name: ML Odds, dtype: int64
# 75   -175
# Name: ML Odds, dtype: int64
# 2155   -1200
# Name: ML Odds, dtype: int64
# 2165   -700
# Name: ML Odds, dtype: int64
# 2335   -140
# Name: ML Odds, dtype: int64
# 117   -700
# Name: ML Odds, dtype: int64
# 167   -130
# Name: ML Odds, dtype: int64
# 181   -485
# Name: ML Odds, dtype: int64
# 202    145
# Name: ML Odds, dtype: int64
# 223   -210
# Name: ML Odds, dtype: int64
# 240   -230
# Name: ML Odds, dtype: int64
# 1569   -175
# Name: ML Odds, dtype: int64
# 1600   -280
# Name: ML Odds, dtype: int64
# 284   -117
# Name: ML Odds, dtype: int64
# 1618   -175
# Name: ML Odds, dtype: int64
# 303   -175
# Name: ML Odds, dtype: int64
# 325   -485
# Name: ML Odds, dtype: int64
# 332    225
# Name: ML Odds, dtype: int64
# 361   -485
# Name: ML Odds, dtype: int64
# 2054   -280
# Name: ML Odds, dtype: int64
# 383   -340
# Name: ML Odds, dtype: int64
# 403   -700
# Name: ML Odds, dtype: int64
# 418   -350
# Name: ML Odds, dtype: int64
# 433   -1250
# Name: ML Odds, dtype: int64
# 2212    165
# Name: ML Odds, dtype: int64
# 1656    175
# Name: ML Odds, dtype: int64
# 510   -135
# Name: ML Odds, dtype: int64
# 532    125
# Name: ML Odds, dtype: int64
# 568    175
# Name: ML Odds, dtype: int64
# 580    100
# Name: ML Odds, dtype: int64
# 2221   -1100
# Name: ML Odds, dtype: int64
# 1699   -1000
# Name: ML Odds, dtype: int64
# 1715   -250
# Name: ML Odds, dtype: int64
# 1725   -3500
# Name: ML Odds, dtype: int64
# 693   -125
# Name: ML Odds, dtype: int64
# 2411   -335
# Name: ML Odds, dtype: int64
# 728   -120
# Name: ML Odds, dtype: int64
# 744    170
# Name: ML Odds, dtype: int64
# 758   -800
# Name: ML Odds, dtype: int64
# 793   -280
# Name: ML Odds, dtype: int64
# 802   -165
# Name: ML Odds, dtype: int64
# 819   -320
# Name: ML Odds, dtype: int64
# 840   -320
# Name: ML Odds, dtype: int64
# 854    155
# Name: ML Odds, dtype: int64
# 881   -290
# Name: ML Odds, dtype: int64
# 1777   -330
# Name: ML Odds, dtype: int64
# 907   -145
# Name: ML Odds, dtype: int64
# 937    100
# Name: ML Odds, dtype: int64
# 945   -200
# Name: ML Odds, dtype: int64
# 972    170
# Name: ML Odds, dtype: int64
# 2242    135
# Name: ML Odds, dtype: int64
# 1812   -320
# Name: ML Odds, dtype: int64
# 1018    155
# Name: ML Odds, dtype: int64
# 1033   -107
# Name: ML Odds, dtype: int64
# 2128   -1100
# Name: ML Odds, dtype: int64
# 2294   -380
# Name: ML Odds, dtype: int64
# 1089    175
# Name: ML Odds, dtype: int64
# 1108   -105
# Name: ML Odds, dtype: int64
# 1860    245
# Name: ML Odds, dtype: int64
# 1150    270
# Name: ML Odds, dtype: int64
# 1907   -240
# Name: ML Odds, dtype: int64
# 1177   -135
# Name: ML Odds, dtype: int64
# 1184    180
# Name: ML Odds, dtype: int64
# 1209   -700
# Name: ML Odds, dtype: int64
# 1238    105
# Name: ML Odds, dtype: int64
# 1259   -1400
# Name: ML Odds, dtype: int64
# 2350   -135
# Name: ML Odds, dtype: int64
# 1281   -102
# Name: ML Odds, dtype: int64
# 1305   -550
# Name: ML Odds, dtype: int64
# 1947   -125
# Name: ML Odds, dtype: int64
# 1968   -440
# Name: ML Odds, dtype: int64
# 1984    135
# Name: ML Odds, dtype: int64
# 2005   -155
# Name: ML Odds, dtype: int64
# 1366   -155
# Name: ML Odds, dtype: int64
# 1388   -220
# Name: ML Odds, dtype: int64
# 2314    135
# Name: ML Odds, dtype: int64
# 2020    125
# Name: ML Odds, dtype: int64
# 1455   -600
# Name: ML Odds, dtype: int64
# 2326    450
# Name: ML Odds, dtype: int64
# 1    135
# Name: ML Odds, dtype: int64
# 30    800
# Name: ML Odds, dtype: int64
# 38   -150
# Name: ML Odds, dtype: int64
# 65    120
# Name: ML Odds, dtype: int64
# 2148    315
# Name: ML Odds, dtype: int64
# 2164    500
# Name: ML Odds, dtype: int64
# 1542    205
# Name: ML Odds, dtype: int64
# 95   -150
# Name: ML Odds, dtype: int64
# 114    385
# Name: ML Odds, dtype: int64
# 138    160
# Name: ML Odds, dtype: int64
# 157    175
# Name: ML Odds, dtype: int64
# 176    155
# Name: ML Odds, dtype: int64
# 199   -112
# Name: ML Odds, dtype: int64
# 216    360
# Name: ML Odds, dtype: int64
# 235    380
# Name: ML Odds, dtype: int64
# 1572    175
# Name: ML Odds, dtype: int64
# 1596    500
# Name: ML Odds, dtype: int64
# 286    1000
# Name: ML Odds, dtype: int64
# 1620    1500
# Name: ML Odds, dtype: int64
# 314    170
# Name: ML Odds, dtype: int64
# 2286    250
# Name: ML Odds, dtype: int64
# 1639    170
# Name: ML Odds, dtype: int64
# 358    320
# Name: ML Odds, dtype: int64
# 2179    150
# Name: ML Odds, dtype: int64
# 382    280
# Name: ML Odds, dtype: int64
# 400    145
# Name: ML Odds, dtype: int64
# 413   -150
# Name: ML Odds, dtype: int64
# 441   -440
# Name: ML Odds, dtype: int64
# 451   -150
# Name: ML Odds, dtype: int64
# 485    160
# Name: ML Odds, dtype: int64
# 1658    210
# Name: ML Odds, dtype: int64
# 2074    200
# Name: ML Odds, dtype: int64
# 517    100
# Name: ML Odds, dtype: int64
# 553    105
# Name: ML Odds, dtype: int64
# 1677   -180
# Name: ML Odds, dtype: int64
# 622    295
# Name: ML Odds, dtype: int64
# 652    140
# Name: ML Odds, dtype: int64
# 1708    700
# Name: ML Odds, dtype: int64
# 1716    500
# Name: ML Odds, dtype: int64
# 1719    325
# Name: ML Odds, dtype: int64
# 691    230
# Name: ML Odds, dtype: int64
# 2413    385
# Name: ML Odds, dtype: int64
# 740    350
# Name: ML Odds, dtype: int64
# 760   -145
# Name: ML Odds, dtype: int64
# 785    115
# Name: ML Odds, dtype: int64
# 1748    800
# Name: ML Odds, dtype: int64
# 2391    155
# Name: ML Odds, dtype: int64
# 857    315
# Name: ML Odds, dtype: int64
# 886    925
# Name: ML Odds, dtype: int64
# 1790    800
# Name: ML Odds, dtype: int64
# 905   -165
# Name: ML Odds, dtype: int64
# 935    210
# Name: ML Odds, dtype: int64
# 2108    468
# Name: ML Odds, dtype: int64
# 943   -210
# Name: ML Odds, dtype: int64
# 969    180
# Name: ML Odds, dtype: int64
# 1001   -380
# Name: ML Odds, dtype: int64
# 1827    135
# Name: ML Odds, dtype: int64
# 1030    600
# Name: ML Odds, dtype: int64
# 1057    105
# Name: ML Odds, dtype: int64
# 1085    155
# Name: ML Odds, dtype: int64
# 1113    100
# Name: ML Odds, dtype: int64
# 1857   -102
# Name: ML Odds, dtype: int64
# 1146    380
# Name: ML Odds, dtype: int64
# 1888    270
# Name: ML Odds, dtype: int64
# 1904    180
# Name: ML Odds, dtype: int64
# 1173    450
# Name: ML Odds, dtype: int64
# 2252    600
# Name: ML Odds, dtype: int64
# 1216    600
# Name: ML Odds, dtype: int64
# 1229    210
# Name: ML Odds, dtype: int64
# 1265   -103
# Name: ML Odds, dtype: int64
# 1279    270
# Name: ML Odds, dtype: int64
# 1299    105
# Name: ML Odds, dtype: int64
# 1961    360
# Name: ML Odds, dtype: int64
# 1990   -155
# Name: ML Odds, dtype: int64
# 2010    325
# Name: ML Odds, dtype: int64
# 1365    315
# Name: ML Odds, dtype: int64
# 1389    180
# Name: ML Odds, dtype: int64
# 2313   -800
# Name: ML Odds, dtype: int64
# 1438    300
# Name: ML Odds, dtype: int64
# 1468    270
# Name: ML Odds, dtype: int64

# %%
spreaddb.to_csv('Spreads.csv')

# %%
moneydb.to_csv('MLodds.csv')

# %%
db.to_csv('2015stats.csv', index = False)

# %%
db['Cover'] = np.zeros(len(db['Team']))
for i in range(len(db['Cover'])):
    cover = db['Team Points'][i] + db['Line'][i] - db['Opp Points'][i]
    if cover > 0:
        db['Cover'][i] = 1
    elif cover < 0:
        db['Cover'][i] = -1
    else:
        db['Cover'][i] = 0
# Out:
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/ahelgeso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
